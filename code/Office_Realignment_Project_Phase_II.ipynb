# %%
# !pip install -q amplpy ampltools
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 15.3 MB/s eta 0:00:00

# %%
# Google Colab & AMPL integration
MODULES, LICENSE_UUID = ["coin", 'gurobi', "cplex", "highs", "gokestrel"], "42fc7eb6-69aa-445d-b655-3ad24d836541"
from amplpy import tools
from ampltools import cloud_platform_name, ampl_notebook, register_magics

# instantiate AMPL object and register magics
if cloud_platform_name() is None:
    ampl = AMPL() # Use local installation of AMPL
else:
    ampl = tools.ampl_notebook(modules=MODULES, license_uuid=LICENSE_UUID, g=globals())

register_magics(ampl_object=ampl)
# Out:
# Licensed to Bundle #6741.7193 expiring 20241231: INFO 645 Prescriptive Analytics, Prof. Paul Brooks, Virginia Commonwealth University.

# %%
from pickle import TRUE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# File path to your Excel file
file_path = '/content/drive/MyDrive/INFO 645/realignment_data_ampl.xlsx'

### Load Data ###

# Load Sheet1: Hours required annually
sheet1_data = pd.read_excel(file_path, sheet_name="Sheet1", header=0)
S = list(sheet1_data.iloc[:, 0])  # Stores
A = sheet1_data.columns[1:].tolist()  # Areas
hours_required = sheet1_data.set_index(sheet1_data.columns[0]).to_dict(orient='index')
print("Hours Required Dictionary Sample:", dict(list(hours_required.items())[:5]))
# Out:
# Hours Required Dictionary Sample: {'Albemarle_County': {'Inventory': 460, 'Payroll': 771, 'Hiring': 0, 'Marketing': 96, 'Merchandising': 90}, 'Amherst_County': {'Inventory': 2, 'Payroll': 28, 'Hiring': 0, 'Marketing': 8, 'Merchandising': 0}, 'Augusta_County': {'Inventory': 341, 'Payroll': 737, 'Hiring': 2806, 'Marketing': 260, 'Merchandising': 65}, 'Buckingham_County': {'Inventory': 46, 'Payroll': 40, 'Hiring': 408, 'Marketing': 84, 'Merchandising': 59}, 'Caroline_County': {'Inventory': 13, 'Payroll': 136, 'Hiring': 170, 'Marketing': 10, 'Merchandising': 55}}

# %%
# Load Sheet3: Hours available
sheet3_data = pd.read_excel(file_path, sheet_name="Sheet3", header=0)
R = list(sheet3_data.iloc[:, 0])  # Regions
hours_available = sheet3_data.set_index(sheet3_data.columns[0]).to_dict(orient='index')
print("Hours Available Dictionary Sample:", dict(list(hours_available.items())[:5]))
# Out:
# Hours Available Dictionary Sample: {'Richmond': {'Inventory': 5000, 'Payroll': 3025, 'Hiring': 1225, 'Marketing': 1750, 'Merchandising': 3675}, 'Tappahannock': {'Inventory': 3400, 'Payroll': 5550, 'Hiring': 3250, 'Marketing': 1200, 'Merchandising': 1600}, 'Warrenton': {'Inventory': 825, 'Payroll': 2500, 'Hiring': 3375, 'Marketing': 1325, 'Merchandising': 850}, 'Staunton': {'Inventory': 3550, 'Payroll': 3450, 'Hiring': 9100, 'Marketing': 1700, 'Merchandising': 1850}}

# %%
# Load mileage data
sheet4_data = pd.read_excel(file_path, sheet_name="Sheet4", header=0)

# Replace '--' or any non-numeric value with 1000
sheet4_data.replace({'--': '1000'}, inplace=True)

# Remove commas and ensure consistent formatting
sheet4_data.iloc[:, 1:] = sheet4_data.iloc[:, 1:].replace({',': ''}, regex=True)

# Convert all columns except the first (stores) to numeric, coercing errors
sheet4_data.iloc[:, 1:] = sheet4_data.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Fill any remaining NaN values with 1000 (e.g., for cells that failed conversion)
sheet4_data.fillna(1000, inplace=True)

# Extract regions (all column headers after the first one)
regions = sheet4_data.columns[1:].tolist()

# Create the mileage dictionary
mileage_dict = {
    row.iloc[0]: {region: row[region] for region in regions}
    for _, row in sheet4_data.iterrows()
}

# Debug: Verify the structure of mileage_dict
print("Extracted Regions:", regions)
print("Mileage Dictionary Sample:\n", dict(list(mileage_dict.items())[:5]))


print("Mileage Dictionary Sample:", dict(list(mileage_dict.items())[:5]))
# Out:
# Extracted Regions: ['Staunton', 'Warrenton', 'Richmond', 'Tappahannock']
# Mileage Dictionary Sample:
#  {'Albemarle_County': {'Staunton': 37, 'Warrenton': 71, 'Richmond': 70, 'Tappahannock': 110}, 'Amherst_County': {'Staunton': 56, 'Warrenton': 1000, 'Richmond': 120, 'Tappahannock': 1000}, 'Augusta_County': {'Staunton': 0, 'Warrenton': 121, 'Richmond': 1000, 'Tappahannock': 1000}, 'Buckingham_County': {'Staunton': 66, 'Warrenton': 108, 'Richmond': 72, 'Tappahannock': 1000}, 'Caroline_County': {'Staunton': 1000, 'Warrenton': 62, 'Richmond': 42, 'Tappahannock': 38}}
# Mileage Dictionary Sample: {'Albemarle_County': {'Staunton': 37, 'Warrenton': 71, 'Richmond': 70, 'Tappahannock': 110}, 'Amherst_County': {'Staunton': 56, 'Warrenton': 1000, 'Richmond': 120, 'Tappahannock': 1000}, 'Augusta_County': {'Staunton': 0, 'Warrenton': 121, 'Richmond': 1000, 'Tappahannock': 1000}, 'Buckingham_County': {'Staunton': 66, 'Warrenton': 108, 'Richmond': 72, 'Tappahannock': 1000}, 'Caroline_County': {'Staunton': 1000, 'Warrenton': 62, 'Richmond': 42, 'Tappahannock': 38}}

# %%
# Load Sheet5: Travel time data
sheet5_data = pd.read_excel(file_path, sheet_name="Sheet5", header=0)
sheet5_data.replace('--', 100, inplace=True)
sheet5_data.iloc[:, 1:] = sheet5_data.iloc[:, 1:].apply(pd.to_numeric)
travel_time_dict = {
    row.iloc[0]: {region: row[region] for region in R}
    for _, row in sheet5_data.iterrows()
}
print("Travel Time Dictionary Sample:", dict(list(travel_time_dict.items())[:5]))
# Out:
# Travel Time Dictionary Sample: {'Albemarle_County': {'Richmond': 1.22, 'Tappahannock': 2.0, 'Warrenton': 1.56, 'Staunton': 0.66}, 'Amherst_County': {'Richmond': 2.1, 'Tappahannock': 100.0, 'Warrenton': 100.0, 'Staunton': 1.08}, 'Augusta_County': {'Richmond': 100.0, 'Tappahannock': 100.0, 'Warrenton': 2.06, 'Staunton': 0.0}, 'Buckingham_County': {'Richmond': 1.55, 'Tappahannock': 100.0, 'Warrenton': 2.43, 'Staunton': 1.3}, 'Caroline_County': {'Richmond': 0.78, 'Tappahannock': 0.82, 'Warrenton': 1.45, 'Staunton': 100.0}}
# <ipython-input-9-fcedc31ed266>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sheet5_data.replace('--', 100, inplace=True)

# %%
# Load Sheet6: Round trips
sheet6_data = pd.read_excel(file_path, sheet_name="Sheet6", header=0)
round_trips = sheet6_data.set_index(sheet6_data.columns[0]).to_dict(orient='index')

### Compute Combined Hours Required ###
hours_required_combined = {}
for store in hours_required:
    for area in hours_required[store]:
        try:
            base_hours = hours_required[store][area]
            travel_hours = sum(
                round_trips[store][area] * travel_time_dict[store][region]
                for region in travel_time_dict[store]
            )
            hours_required_combined[(store, area)] = base_hours + travel_hours
        except KeyError as e:
            print(f"Missing data for {store} in area {area}: {e}")

# Flatten hours_available
hours_available_flat = {
    (region, area): hours_available[region][area]
    for region in hours_available
    for area in hours_available[region]
}

### Debugging Outputs ###
print("Stores (S):", S)
print("Areas (A):", A)
print("Regions (R):", R)
print("\nCombined Hours Required (Sample):", dict(list(hours_required_combined.items())[:5]))
print("\nFlattened Hours Available (Sample):", dict(list(hours_available_flat.items())[:5]))
# Out:
# Stores (S): ['Albemarle_County', 'Amherst_County', 'Augusta_County', 'Buckingham_County', 'Caroline_County', 'Charles_City_County', 'Chesterfield_County', 'City_of_Fredericksburg', 'City_of_Richmond', 'Culpeper_County', 'Cumberland_County', 'Dinwiddie_County', 'Essex_County', 'Fauquier_County', 'Fluvanna_County', 'Goochland_County', 'Greene_County', 'Hanover_County', 'Henrico_County', 'Hopewell_County', 'James_City_County', 'King_and_Queen_County', 'King_George_County', 'King_William_County', 'Louisa_County', 'Madison_County', 'Mathews_County', 'Nelson_County', 'New_Kent_County', 'Orange_County', 'Page_County', 'Powhatan_County', 'Prince_George_County', 'Prince_William_County', 'Rappahannock_County', 'Rockbridge_County', 'Rockingham_County', 'Shenandoah_County', 'Spotsylvania_County', 'Stafford_County', 'Warren_County', 'Westmoreland_County', 'York_County']
# Areas (A): ['Inventory', 'Payroll', 'Hiring', 'Marketing', 'Merchandising']
# Regions (R): ['Richmond', 'Tappahannock', 'Warrenton', 'Staunton']
#
# Combined Hours Required (Sample): {('Albemarle_County', 'Inventory'): 884.32, ('Albemarle_County', 'Payroll'): 2218.04, ('Albemarle_County', 'Hiring'): 0.0, ('Albemarle_County', 'Marketing'): 302.72, ('Albemarle_County', 'Merchandising'): 144.4}
#
# Flattened Hours Available (Sample): {('Richmond', 'Inventory'): 5000, ('Richmond', 'Payroll'): 3025, ('Richmond', 'Hiring'): 1225, ('Richmond', 'Marketing'): 1750, ('Richmond', 'Merchandising'): 3675}

# %%
# Prepare data for AMPL
AMPL_data = {
    'R': R,  # Regions
    'S': S,  # Stores
    'A': A,  # Areas
    'hours_required': hours_required_combined,  # Hours required by store and area
    'hours_available': hours_available_flat,  # Hours available by region and area
    'mileage': mileage_dict,  # Two-dimensional dictionary: mileage[store][region]
    'travel_time': travel_time_dict,  # Two-dimensional dictionary: travel_time[store][region]
    'round_trips': round_trips  # Total round trips for each store and area
}

# Debugging and Verification
print("\n===== Debugging Data Verification =====\n")

# Display regions
if 'R' in AMPL_data:
    print("Regions (R):", ", ".join(AMPL_data['R']))
else:
    print("Regions (R): Data not found.")

# Display stores
if 'S' in AMPL_data:
    print("\nStores (S):", ", ".join(AMPL_data['S']))
else:
    print("\nStores (S): Data not found.")

# Display areas
if 'A' in AMPL_data:
    print("\nAreas (A):", ", ".join(AMPL_data['A']))
else:
    print("\nAreas (A): Data not found.")

# Display a sample of hours_required
if 'hours_required' in AMPL_data:
    print("\nHours Required by Stores and Areas (Sample):")
    print(dict(list(AMPL_data['hours_required'].items())[:5]))
else:
    print("\nHours Required by Stores and Areas: Data not found.")

# Display a sample of hours_available
if 'hours_available' in AMPL_data:
    print("\nHours Available by Regions and Areas (Sample):")
    print(dict(list(AMPL_data['hours_available'].items())[:5]))
else:
    print("\nHours Available by Regions and Areas: Data not found.")

# Display mileage dictionary sample
if 'mileage' in AMPL_data:
    print("\nMileage Dictionary (Sample):")
    print(dict(list(AMPL_data['mileage'].items())[:5]))
else:
    print("\nMileage Dictionary: Data not found.")

# Display travel time dictionary sample
if 'travel_time' in AMPL_data:
    print("\nTravel Time Dictionary (Sample):")
    print(dict(list(AMPL_data['travel_time'].items())[:5]))
else:
    print("\nTravel Time Dictionary: Data not found.")

# Display round trips sample
if 'round_trips' in AMPL_data:
    print("\nRound Trips (Sample):")
    print(dict(list(AMPL_data['round_trips'].items())[:5]))
else:
    print("\nRound Trips: Data not found.")
# Out:
# ===== Debugging Data Verification =====
#
# Regions (R): Richmond, Tappahannock, Warrenton, Staunton
#
# Stores (S): Albemarle_County, Amherst_County, Augusta_County, Buckingham_County, Caroline_County, Charles_City_County, Chesterfield_County, City_of_Fredericksburg, City_of_Richmond, Culpeper_County, Cumberland_County, Dinwiddie_County, Essex_County, Fauquier_County, Fluvanna_County, Goochland_County, Greene_County, Hanover_County, Henrico_County, Hopewell_County, James_City_County, King_and_Queen_County, King_George_County, King_William_County, Louisa_County, Madison_County, Mathews_County, Nelson_County, New_Kent_County, Orange_County, Page_County, Powhatan_County, Prince_George_County, Prince_William_County, Rappahannock_County, Rockbridge_County, Rockingham_County, Shenandoah_County, Spotsylvania_County, Stafford_County, Warren_County, Westmoreland_County, York_County
#
# Areas (A): Inventory, Payroll, Hiring, Marketing, Merchandising
#
# Hours Required by Stores and Areas (Sample):
# {('Albemarle_County', 'Inventory'): 884.32, ('Albemarle_County', 'Payroll'): 2218.04, ('Albemarle_County', 'Hiring'): 0.0, ('Albemarle_County', 'Marketing'): 302.72, ('Albemarle_County', 'Merchandising'): 144.4}
#
# Hours Available by Regions and Areas (Sample):
# {('Richmond', 'Inventory'): 5000, ('Richmond', 'Payroll'): 3025, ('Richmond', 'Hiring'): 1225, ('Richmond', 'Marketing'): 1750, ('Richmond', 'Merchandising'): 3675}
#
# Mileage Dictionary (Sample):
# {'Albemarle_County': {'Staunton': 37, 'Warrenton': 71, 'Richmond': 70, 'Tappahannock': 110}, 'Amherst_County': {'Staunton': 56, 'Warrenton': 1000, 'Richmond': 120, 'Tappahannock': 1000}, 'Augusta_County': {'Staunton': 0, 'Warrenton': 121, 'Richmond': 1000, 'Tappahannock': 1000}, 'Buckingham_County': {'Staunton': 66, 'Warrenton': 108, 'Richmond': 72, 'Tappahannock': 1000}, 'Caroline_County': {'Staunton': 1000, 'Warrenton': 62, 'Richmond': 42, 'Tappahannock': 38}}
#
# Travel Time Dictionary (Sample):
# {'Albemarle_County': {'Richmond': 1.22, 'Tappahannock': 2.0, 'Warrenton': 1.56, 'Staunton': 0.66}, 'Amherst_County': {'Richmond': 2.1, 'Tappahannock': 100.0, 'Warrenton': 100.0, 'Staunton': 1.08}, 'Augusta_County': {'Richmond': 100.0, 'Tappahannock': 100.0, 'Warrenton': 2.06, 'Staunton': 0.0}, 'Buckingham_County': {'Richmond': 1.55, 'Tappahannock': 100.0, 'Warrenton': 2.43, 'Staunton': 1.3}, 'Caroline_County': {'Richmond': 0.78, 'Tappahannock': 0.82, 'Warrenton': 1.45, 'Staunton': 100.0}}
#
# Round Trips (Sample):
# {'Albemarle_County': {'Inventory': 78, 'Payroll': 266, 'Hiring': 0, 'Marketing': 38, 'Merchandising': 10, 'Sum_total': 392}, 'Amherst_County': {'Inventory': 0, 'Payroll': 22, 'Hiring': 0, 'Marketing': 2, 'Merchandising': 0, 'Sum_total': 24}, 'Augusta_County': {'Inventory': 184, 'Payroll': 182, 'Hiring': 372, 'Marketing': 60, 'Merchandising': 60, 'Sum_total': 858}, 'Buckingham_County': {'Inventory': 4, 'Payroll': 4, 'Hiring': 46, 'Marketing': 30, 'Merchandising': 8, 'Sum_total': 92}, 'Caroline_County': {'Inventory': 8, 'Payroll': 34, 'Hiring': 12, 'Marketing': 10, 'Merchandising': 8, 'Sum_total': 72}}

# %%
ampl.eval('''

reset;

# Sets
set R;   # Regions
set S;   # Stores
set A;   # Areas

# Parameters
param mileage_cost >= 0 default 0.585;  # Mileage cost per mile
param salary_per_hour >= 0 default 26;  # Salary cost per hour

# Data Parameters
param mileage{S, R} >= 0;      # Mileage distance from each store to each region
param travel_time{S, R} >= 0;  # Travel time from each store to each region (in hours)
param base_hours_required{S, A} >= 0;  # Base hours required annually by each store for each area
param hours_available{R, A} >= 0;      # Hours available annually for each region for each area
param round_trips{S, A} >= 0;          # Number of round trips for each store and area

# Decision Variables
var x{S, R} binary;     # Binary decision variable: 1 if store j is assigned to region i, 0 otherwise

# Objective Function
minimize TotalCost:
    sum {j in S, i in R}
        x[j, i] * (
            mileage_cost * mileage[j, i] * sum {a in A} round_trips[j, a]  # Total mileage cost
            + salary_per_hour * travel_time[j, i] * sum {a in A} round_trips[j, a]  # Total salary cost
        );

# Constraints

# 1. Each store must be assigned to exactly one region
subject to AssignEachStoreOnce {j in S}:
    sum {i in R} x[j, i] = 1;

# 2. Hours required by stores in each region for each area must not exceed available hours
subject to HoursConstraint {i in R, a in A}:
    sum {j in S} x[j, i] * (
        base_hours_required[j, a]  # Base hours from Sheet1
        + round_trips[j, a] * travel_time[j, i]  # Travel hours
    ) <= hours_available[i, a];

''')

# %%
# Debugging and Verification
print("\n===== Debugging Data Verification =====\n")

# Display the list of regions
print("Regions (R):")
print(AMPL_data['R'])

# Display the list of stores
print("\nStores (S):")
print(AMPL_data['S'])

# Display hours required (showing only the first 5 entries for brevity)
print("\nHours Required (Sample):")
for key, value in list(AMPL_data['hours_required'].items())[:5]:
    print(f"Store {key[0]}, Area {key[1]}: {value}")

# Display hours available (showing only the first 5 entries for brevity)
print("\nHours Available (Sample):")
for key, value in list(AMPL_data['hours_available'].items())[:5]:
    print(f"Region {key[0]}, Area {key[1]}: {value}")

# Display travel time for the first store
print("\nTravel Time (First Store):")
first_store = list(AMPL_data['travel_time'].keys())[0]
print(f"Store: {first_store}, Travel Times: {AMPL_data['travel_time'][first_store]}")

# Display round trips
print("\nRound Trips (Sample):")
for key, value in list(AMPL_data['round_trips'].items())[:5]:
    print(f"Store {key[0]}, Area {key[1]}: {value}")

# Display mileage for the first store
print("\nMileage (First Store):")
first_store = list(AMPL_data['mileage'].keys())[0]
print(f"Store: {first_store}, Mileage: {AMPL_data['mileage'][first_store]}")
# Out:
# ===== Debugging Data Verification =====
#
# Regions (R):
# ['Richmond', 'Tappahannock', 'Warrenton', 'Staunton']
#
# Stores (S):
# ['Albemarle_County', 'Amherst_County', 'Augusta_County', 'Buckingham_County', 'Caroline_County', 'Charles_City_County', 'Chesterfield_County', 'City_of_Fredericksburg', 'City_of_Richmond', 'Culpeper_County', 'Cumberland_County', 'Dinwiddie_County', 'Essex_County', 'Fauquier_County', 'Fluvanna_County', 'Goochland_County', 'Greene_County', 'Hanover_County', 'Henrico_County', 'Hopewell_County', 'James_City_County', 'King_and_Queen_County', 'King_George_County', 'King_William_County', 'Louisa_County', 'Madison_County', 'Mathews_County', 'Nelson_County', 'New_Kent_County', 'Orange_County', 'Page_County', 'Powhatan_County', 'Prince_George_County', 'Prince_William_County', 'Rappahannock_County', 'Rockbridge_County', 'Rockingham_County', 'Shenandoah_County', 'Spotsylvania_County', 'Stafford_County', 'Warren_County', 'Westmoreland_County', 'York_County']
#
# Hours Required (Sample):
# Store Albemarle_County, Area Inventory: 884.32
# Store Albemarle_County, Area Payroll: 2218.04
# Store Albemarle_County, Area Hiring: 0.0
# Store Albemarle_County, Area Marketing: 302.72
# Store Albemarle_County, Area Merchandising: 144.4
#
# Hours Available (Sample):
# Region Richmond, Area Inventory: 5000
# Region Richmond, Area Payroll: 3025
# Region Richmond, Area Hiring: 1225
# Region Richmond, Area Marketing: 1750
# Region Richmond, Area Merchandising: 3675
#
# Travel Time (First Store):
# Store: Albemarle_County, Travel Times: {'Richmond': 1.22, 'Tappahannock': 2.0, 'Warrenton': 1.56, 'Staunton': 0.66}
#
# Round Trips (Sample):
# Store A, Area l: {'Inventory': 78, 'Payroll': 266, 'Hiring': 0, 'Marketing': 38, 'Merchandising': 10, 'Sum_total': 392}
# Store A, Area m: {'Inventory': 0, 'Payroll': 22, 'Hiring': 0, 'Marketing': 2, 'Merchandising': 0, 'Sum_total': 24}
# Store A, Area u: {'Inventory': 184, 'Payroll': 182, 'Hiring': 372, 'Marketing': 60, 'Merchandising': 60, 'Sum_total': 858}
# Store B, Area u: {'Inventory': 4, 'Payroll': 4, 'Hiring': 46, 'Marketing': 30, 'Merchandising': 8, 'Sum_total': 92}
# Store C, Area a: {'Inventory': 8, 'Payroll': 34, 'Hiring': 12, 'Marketing': 10, 'Merchandising': 8, 'Sum_total': 72}
#
# Mileage (First Store):
# Store: Albemarle_County, Mileage: {'Staunton': 37, 'Warrenton': 71, 'Richmond': 70, 'Tappahannock': 110}

# %%
# Assign sets
ampl.set['R'] = R  # Regions
ampl.set['S'] = S  # Stores
ampl.set['A'] = A  # Areas

# Assign parameters
# Mileage: Flatten the nested dictionary to pass to AMPL
ampl.param['mileage'] = {
    (store, region): mileage_dict[store][region]
    for store in S  # Ensure only stores in S are included
    for region in R  # Ensure only regions in R are included
}

# Travel Time: Flatten the nested dictionary to pass to AMPL
ampl.param['travel_time'] = {
    (store, region): travel_time_dict[store][region]
    for store in S  # Ensure only stores in S are included
    for region in R  # Ensure only regions in R are included
}

# Round Trips: Flatten round trips (area-specific)
round_trips_flat = {
    (store, area): round_trips[store][area]
    for store in S  # Ensure only stores in S are included
    for area in A  # Ensure only areas in A are included
}
ampl.param['round_trips'] = round_trips_flat

# Base Hours Required: Flatten base hours (from Sheet1) to handle store x area structure
base_hours_required_flat = {
    (store, area): hours_required[store][area]
    for store in S  # Ensure only stores in S are included
    for area in A  # Ensure only areas in A are included
}
ampl.param['base_hours_required'] = base_hours_required_flat

# Hours Available: Flatten to handle region x area structure
hours_available_flat = {
    (region, area): hours_available[region][area]
    for region in R  # Ensure only regions in R are included
    for area in A  # Ensure only areas in A are included
}
ampl.param['hours_available'] = hours_available_flat

# %%
# Expand and display variables
ampl.eval('expand x;')

# Expand and display constraints
ampl.eval('expand AssignEachStoreOnce;')
ampl.eval('expand HoursConstraint;')
# Out:
# Coefficients of x['Albemarle_County','Richmond']:
# 	AssignEachStoreOnce['Albemarle_County']          1
# 	HoursConstraint['Richmond','Inventory']        555.16
# 	HoursConstraint['Richmond','Payroll']         1095.52
# 	HoursConstraint['Richmond','Marketing']        142.36
# 	HoursConstraint['Richmond','Merchandising']    102.2
# 	TotalCost                                    28486.6
#
# Coefficients of x['Albemarle_County','Tappahannock']:
# 	AssignEachStoreOnce['Albemarle_County']              1
# 	HoursConstraint['Tappahannock','Inventory']        616
# 	HoursConstraint['Tappahannock','Payroll']         1303
# 	HoursConstraint['Tappahannock','Marketing']        172
# 	HoursConstraint['Tappahannock','Merchandising']    110
# 	TotalCost                                        45609.2
#
# Coefficients of x['Albemarle_County','Warrenton']:
# 	AssignEachStoreOnce['Albemarle_County']           1
# 	HoursConstraint['Warrenton','Inventory']        581.68
# 	HoursConstraint['Warrenton','Payroll']         1185.96
# 	HoursConstraint['Warrenton','Marketing']        155.28
# 	HoursConstraint['Warrenton','Merchandising']    105.6
# 	TotalCost                                     32181.2
#
# Coefficients of x['Albemarle_County','Staunton']:
# 	AssignEachStoreOnce['Albemarle_County']          1
# 	HoursConstraint['Staunton','Inventory']        511.48
# 	HoursConstraint['Staunton','Payroll']          946.56
# 	HoursConstraint['Staunton','Marketing']        121.08
# 	HoursConstraint['Staunton','Merchandising']     96.6
# 	TotalCost                                    15211.6
#
# Coefficients of x['Amherst_County','Richmond']:
# 	AssignEachStoreOnce['Amherst_County']       1
# 	HoursConstraint['Richmond','Inventory']     2
# 	HoursConstraint['Richmond','Payroll']      74.2
# 	HoursConstraint['Richmond','Marketing']    12.2
# 	TotalCost                                2995.2
#
# Coefficients of x['Amherst_County','Tappahannock']:
# 	AssignEachStoreOnce['Amherst_County']            1
# 	HoursConstraint['Tappahannock','Inventory']      2
# 	HoursConstraint['Tappahannock','Payroll']     2228
# 	HoursConstraint['Tappahannock','Marketing']    208
# 	TotalCost                                    76440
#
# Coefficients of x['Amherst_County','Warrenton']:
# 	AssignEachStoreOnce['Amherst_County']         1
# 	HoursConstraint['Warrenton','Inventory']      2
# 	HoursConstraint['Warrenton','Payroll']     2228
# 	HoursConstraint['Warrenton','Marketing']    208
# 	TotalCost                                 76440
#
# Coefficients of x['Amherst_County','Staunton']:
# 	AssignEachStoreOnce['Amherst_County']       1
# 	HoursConstraint['Staunton','Inventory']     2
# 	HoursConstraint['Staunton','Payroll']      51.76
# 	HoursConstraint['Staunton','Marketing']    10.16
# 	TotalCost                                1460.16
#
# Coefficients of x['Augusta_County','Richmond']:
# 	AssignEachStoreOnce['Augusta_County']              1
# 	HoursConstraint['Richmond','Inventory']        18741
# 	HoursConstraint['Richmond','Payroll']          18937
# 	HoursConstraint['Richmond','Hiring']           40006
# 	HoursConstraint['Richmond','Marketing']         6260
# 	HoursConstraint['Richmond','Merchandising']     6065
# 	TotalCost                                    2732730
#
# Coefficients of x['Augusta_County','Tappahannock']:
# 	AssignEachStoreOnce['Augusta_County']                  1
# 	HoursConstraint['Tappahannock','Inventory']        18741
# 	HoursConstraint['Tappahannock','Payroll']          18937
# 	HoursConstraint['Tappahannock','Hiring']           40006
# 	HoursConstraint['Tappahannock','Marketing']         6260
# 	HoursConstraint['Tappahannock','Merchandising']     6065
# 	TotalCost                                        2732730
#
# Coefficients of x['Augusta_County','Warrenton']:
# 	AssignEachStoreOnce['Augusta_County']              1
# 	HoursConstraint['Warrenton','Inventory']         720.04
# 	HoursConstraint['Warrenton','Payroll']          1111.92
# 	HoursConstraint['Warrenton','Hiring']           3572.32
# 	HoursConstraint['Warrenton','Marketing']         383.6
# 	HoursConstraint['Warrenton','Merchandising']     188.6
# 	TotalCost                                     106688
#
# Coefficients of x['Augusta_County','Staunton']:
# 	AssignEachStoreOnce['Augusta_County']           1
# 	HoursConstraint['Staunton','Inventory']       341
# 	HoursConstraint['Staunton','Payroll']         737
# 	HoursConstraint['Staunton','Hiring']         2806
# 	HoursConstraint['Staunton','Marketing']       260
# 	HoursConstraint['Staunton','Merchandising']    65
#
# Coefficients of x['Buckingham_County','Richmond']:
# 	AssignEachStoreOnce['Buckingham_County']        1
# 	HoursConstraint['Richmond','Inventory']        52.2
# 	HoursConstraint['Richmond','Payroll']          46.2
# 	HoursConstraint['Richmond','Hiring']          479.3
# 	HoursConstraint['Richmond','Marketing']       130.5
# 	HoursConstraint['Richmond','Merchandising']    71.4
# 	TotalCost                                    7582.64
#
# Coefficients of x['Buckingham_County','Tappahannock']:
# 	AssignEachStoreOnce['Buckingham_County']              1
# 	HoursConstraint['Tappahannock','Inventory']         446
# 	HoursConstraint['Tappahannock','Payroll']           440
# 	HoursConstraint['Tappahannock','Hiring']           5008
# 	HoursConstraint['Tappahannock','Marketing']        3084
# 	HoursConstraint['Tappahannock','Merchandising']     859
# 	TotalCost                                        293020
#
# Coefficients of x['Buckingham_County','Warrenton']:
# 	AssignEachStoreOnce['Buckingham_County']          1
# 	HoursConstraint['Warrenton','Inventory']         55.72
# 	HoursConstraint['Warrenton','Payroll']           49.72
# 	HoursConstraint['Warrenton','Hiring']           519.78
# 	HoursConstraint['Warrenton','Marketing']        156.9
# 	HoursConstraint['Warrenton','Merchandising']     78.44
# 	TotalCost                                     11625.1
#
# Coefficients of x['Buckingham_County','Staunton']:
# 	AssignEachStoreOnce['Buckingham_County']        1
# 	HoursConstraint['Staunton','Inventory']        51.2
# 	HoursConstraint['Staunton','Payroll']          45.2
# 	HoursConstraint['Staunton','Hiring']          467.8
# 	HoursConstraint['Staunton','Marketing']       123
# 	HoursConstraint['Staunton','Merchandising']    69.4
# 	TotalCost                                    6661.72
#
# Coefficients of x['Caroline_County','Richmond']:
# 	AssignEachStoreOnce['Caroline_County']          1
# 	HoursConstraint['Richmond','Inventory']        19.24
# 	HoursConstraint['Richmond','Payroll']         162.52
# 	HoursConstraint['Richmond','Hiring']          179.36
# 	HoursConstraint['Richmond','Marketing']        17.8
# 	HoursConstraint['Richmond','Merchandising']    61.24
# 	TotalCost                                    3229.2
#
# Coefficients of x['Caroline_County','Tappahannock']:
# 	AssignEachStoreOnce['Caroline_County']              1
# 	HoursConstraint['Tappahannock','Inventory']        19.56
# 	HoursConstraint['Tappahannock','Payroll']         163.88
# 	HoursConstraint['Tappahannock','Hiring']          179.84
# 	HoursConstraint['Tappahannock','Marketing']        18.2
# 	HoursConstraint['Tappahannock','Merchandising']    61.56
# 	TotalCost                                        3135.6
#
# Coefficients of x['Caroline_County','Warrenton']:
# 	AssignEachStoreOnce['Caroline_County']           1
# 	HoursConstraint['Warrenton','Inventory']        24.6
# 	HoursConstraint['Warrenton','Payroll']         185.3
# 	HoursConstraint['Warrenton','Hiring']          187.4
# 	HoursConstraint['Warrenton','Marketing']        24.5
# 	HoursConstraint['Warrenton','Merchandising']    66.6
# 	TotalCost                                     5325.84
#
# Coefficients of x['Caroline_County','Staunton']:
# 	AssignEachStoreOnce['Caroline_County']            1
# 	HoursConstraint['Staunton','Inventory']         813
# 	HoursConstraint['Staunton','Payroll']          3536
# 	HoursConstraint['Staunton','Hiring']           1370
# 	HoursConstraint['Staunton','Marketing']        1010
# 	HoursConstraint['Staunton','Merchandising']     855
# 	TotalCost                                    229320
#
# Coefficients of x['Charles_City_County','Richmond']:
# 	AssignEachStoreOnce['Charles_City_County']      1
# 	HoursConstraint['Richmond','Inventory']       133.68
# 	HoursConstraint['Richmond','Payroll']          35.36
# 	HoursConstraint['Richmond','Marketing']        55.6
# 	HoursConstraint['Richmond','Merchandising']    16.56
# 	TotalCost                                    3773.25
#
# Coefficients of x['Charles_City_County','Tappahannock']:
# 	AssignEachStoreOnce['Charles_City_County']          1
# 	HoursConstraint['Tappahannock','Inventory']       175.12
# 	HoursConstraint['Tappahannock','Payroll']          44.24
# 	HoursConstraint['Tappahannock','Marketing']        70.4
# 	HoursConstraint['Tappahannock','Merchandising']    18.04
# 	TotalCost                                        7347.6
#
# Coefficients of x['Charles_City_County','Warrenton']:
# 	AssignEachStoreOnce['Charles_City_County']         1
# 	HoursConstraint['Warrenton','Inventory']        5690
# 	HoursConstraint['Warrenton','Payroll']          1226
# 	HoursConstraint['Warrenton','Marketing']        2040
# 	HoursConstraint['Warrenton','Merchandising']     215
# 	TotalCost                                     286650
#
# Coefficients of x['Charles_City_County','Staunton']:
# 	AssignEachStoreOnce['Charles_City_County']        1
# 	HoursConstraint['Staunton','Inventory']        5690
# 	HoursConstraint['Staunton','Payroll']          1226
# 	HoursConstraint['Staunton','Marketing']        2040
# 	HoursConstraint['Staunton','Merchandising']     215
# 	TotalCost                                    286650
#
# Coefficients of x['Chesterfield_County','Richmond']:
# 	AssignEachStoreOnce['Chesterfield_County']      1
# 	HoursConstraint['Richmond','Inventory']       696.8
# 	HoursConstraint['Richmond','Payroll']         403.8
# 	HoursConstraint['Richmond','Hiring']           19.28
# 	HoursConstraint['Richmond','Marketing']       153.12
# 	HoursConstraint['Richmond','Merchandising']    10.28
# 	TotalCost                                    6603.48
#
# Coefficients of x['Chesterfield_County','Tappahannock']:
# 	AssignEachStoreOnce['Chesterfield_County']           1
# 	HoursConstraint['Tappahannock','Inventory']        800.2
# 	HoursConstraint['Tappahannock','Payroll']          554.2
# 	HoursConstraint['Tappahannock','Hiring']            24.92
# 	HoursConstraint['Tappahannock','Marketing']        175.68
# 	HoursConstraint['Tappahannock','Merchandising']     15.92
# 	TotalCost                                        22137.6
#
# Coefficients of x['Chesterfield_County','Warrenton']:
# 	AssignEachStoreOnce['Chesterfield_County']        1
# 	HoursConstraint['Warrenton','Inventory']        883.8
# 	HoursConstraint['Warrenton','Payroll']          675.8
# 	HoursConstraint['Warrenton','Hiring']            29.48
# 	HoursConstraint['Warrenton','Marketing']        193.92
# 	HoursConstraint['Warrenton','Merchandising']     20.48
# 	TotalCost                                     36597.6
#
# Coefficients of x['Chesterfield_County','Staunton']:
# 	AssignEachStoreOnce['Chesterfield_County']        1
# 	HoursConstraint['Staunton','Inventory']       11655
# 	HoursConstraint['Staunton','Payroll']         16343
# 	HoursConstraint['Staunton','Hiring']            617
# 	HoursConstraint['Staunton','Marketing']        2544
# 	HoursConstraint['Staunton','Merchandising']     608
# 	TotalCost                                    974610
#
# Coefficients of x['City_of_Fredericksburg','Richmond']:
# 	AssignEachStoreOnce['City_of_Fredericksburg']     1
# 	HoursConstraint['Richmond','Inventory']         162.14
# 	HoursConstraint['Richmond','Payroll']            80.48
# 	HoursConstraint['Richmond','Hiring']             64.12
# 	HoursConstraint['Richmond','Merchandising']      82.36
# 	TotalCost                                      4290.65
#
# Coefficients of x['City_of_Fredericksburg','Tappahannock']:
# 	AssignEachStoreOnce['City_of_Fredericksburg']       1
# 	HoursConstraint['Tappahannock','Inventory']       164.04
# 	HoursConstraint['Tappahannock','Payroll']          81.28
# 	HoursConstraint['Tappahannock','Hiring']           64.32
# 	HoursConstraint['Tappahannock','Merchandising']    82.96
# 	TotalCost                                        3890.25
#
# Coefficients of x['City_of_Fredericksburg','Warrenton']:
# 	AssignEachStoreOnce['City_of_Fredericksburg']     1
# 	HoursConstraint['Warrenton','Inventory']        159.48
# 	HoursConstraint['Warrenton','Payroll']           79.36
# 	HoursConstraint['Warrenton','Hiring']            63.84
# 	HoursConstraint['Warrenton','Merchandising']     81.52
# 	TotalCost                                      3303.3
#
# Coefficients of x['City_of_Fredericksburg','Staunton']:
# 	AssignEachStoreOnce['City_of_Fredericksburg']     1
# 	HoursConstraint['Staunton','Inventory']         205.84
# 	HoursConstraint['Staunton','Payroll']            98.88
# 	HoursConstraint['Staunton','Hiring']             68.72
# 	HoursConstraint['Staunton','Merchandising']      96.16
# 	TotalCost                                      8513.05
#
# Coefficients of x['City_of_Richmond','Richmond']:
# 	AssignEachStoreOnce['City_of_Richmond']        1
# 	HoursConstraint['Richmond','Inventory']      468
# 	HoursConstraint['Richmond','Payroll']        264
# 	HoursConstraint['Richmond','Merchandising']    2
#
# Coefficients of x['City_of_Richmond','Tappahannock']:
# 	AssignEachStoreOnce['City_of_Richmond']              1
# 	HoursConstraint['Tappahannock','Inventory']        548.36
# 	HoursConstraint['Tappahannock','Payroll']          401.2
# 	HoursConstraint['Tappahannock','Merchandising']      3.96
# 	TotalCost                                        11735.4
#
# Coefficients of x['City_of_Richmond','Warrenton']:
# 	AssignEachStoreOnce['City_of_Richmond']           1
# 	HoursConstraint['Warrenton','Inventory']        619.7
# 	HoursConstraint['Warrenton','Payroll']          523
# 	HoursConstraint['Warrenton','Merchandising']      5.7
# 	TotalCost                                     21781.8
#
# Coefficients of x['City_of_Richmond','Staunton']:
# 	AssignEachStoreOnce['City_of_Richmond']           1
# 	HoursConstraint['Staunton','Inventory']        8668
# 	HoursConstraint['Staunton','Payroll']         14264
# 	HoursConstraint['Staunton','Merchandising']     202
# 	TotalCost                                    713440
#
# Coefficients of x['Culpeper_County','Richmond']:
# 	AssignEachStoreOnce['Culpeper_County']          1
# 	HoursConstraint['Richmond','Inventory']        26
# 	HoursConstraint['Richmond','Payroll']         138
# 	HoursConstraint['Richmond','Hiring']          228
# 	HoursConstraint['Richmond','Merchandising']   137.5
# 	TotalCost                                    5658.77
#
# Coefficients of x['Culpeper_County','Tappahannock']:
# 	AssignEachStoreOnce['Culpeper_County']              1
# 	HoursConstraint['Tappahannock','Inventory']        27.44
# 	HoursConstraint['Tappahannock','Payroll']         142.32
# 	HoursConstraint['Tappahannock','Hiring']          230.88
# 	HoursConstraint['Tappahannock','Merchandising']   139.3
# 	TotalCost                                        5760.56
#
# Coefficients of x['Culpeper_County','Warrenton']:
# 	AssignEachStoreOnce['Culpeper_County']           1
# 	HoursConstraint['Warrenton','Inventory']        16.8
# 	HoursConstraint['Warrenton','Payroll']         110.4
# 	HoursConstraint['Warrenton','Hiring']          209.6
# 	HoursConstraint['Warrenton','Merchandising']   126
# 	TotalCost                                     1753.05
#
# Coefficients of x['Culpeper_County','Staunton']:
# 	AssignEachStoreOnce['Culpeper_County']          1
# 	HoursConstraint['Staunton','Inventory']        24.24
# 	HoursConstraint['Staunton','Payroll']         132.72
# 	HoursConstraint['Staunton','Hiring']          224.48
# 	HoursConstraint['Staunton','Merchandising']   135.3
# 	TotalCost                                    5021.64
#
# Coefficients of x['Cumberland_County','Richmond']:
# 	AssignEachStoreOnce['Cumberland_County']     1
# 	HoursConstraint['Richmond','Inventory']     36.82
# 	HoursConstraint['Richmond','Payroll']       51.08
# 	HoursConstraint['Richmond','Hiring']        42.94
# 	HoursConstraint['Richmond','Marketing']     18.52
# 	TotalCost                                 4347.72
#
# Coefficients of x['Cumberland_County','Tappahannock']:
# 	AssignEachStoreOnce['Cumberland_County']        1
# 	HoursConstraint['Tappahannock','Inventory']    49.42
# 	HoursConstraint['Tappahannock','Payroll']      65.48
# 	HoursConstraint['Tappahannock','Hiring']       77.14
# 	HoursConstraint['Tappahannock','Marketing']    22.12
# 	TotalCost                                    8054.28
#
# Coefficients of x['Cumberland_County','Warrenton']:
# 	AssignEachStoreOnce['Cumberland_County']     1
# 	HoursConstraint['Warrenton','Inventory']    55.02
# 	HoursConstraint['Warrenton','Payroll']      71.88
# 	HoursConstraint['Warrenton','Hiring']       92.34
# 	HoursConstraint['Warrenton','Marketing']    23.72
# 	TotalCost                                 9097.92
#
# Coefficients of x['Cumberland_County','Staunton']:
# 	AssignEachStoreOnce['Cumberland_County']     1
# 	HoursConstraint['Staunton','Inventory']     45.08
# 	HoursConstraint['Staunton','Payroll']       60.52
# 	HoursConstraint['Staunton','Hiring']        65.36
# 	HoursConstraint['Staunton','Marketing']     20.88
# 	TotalCost                                 6926.4
#
# Coefficients of x['Dinwiddie_County','Richmond']:
# 	AssignEachStoreOnce['Dinwiddie_County']          1
# 	HoursConstraint['Richmond','Inventory']        352.5
# 	HoursConstraint['Richmond','Payroll']          257
# 	HoursConstraint['Richmond','Hiring']           516
# 	HoursConstraint['Richmond','Marketing']        181
# 	HoursConstraint['Richmond','Merchandising']     57.5
# 	TotalCost                                    10639.2
#
# Coefficients of x['Dinwiddie_County','Tappahannock']:
# 	AssignEachStoreOnce['Dinwiddie_County']              1
# 	HoursConstraint['Tappahannock','Inventory']        417.6
# 	HoursConstraint['Tappahannock','Payroll']          342.56
# 	HoursConstraint['Tappahannock','Hiring']           560.64
# 	HoursConstraint['Tappahannock','Marketing']        207.04
# 	HoursConstraint['Tappahannock','Merchandising']     66.8
# 	TotalCost                                        23164.4
#
# Coefficients of x['Dinwiddie_County','Warrenton']:
# 	AssignEachStoreOnce['Dinwiddie_County']            1
# 	HoursConstraint['Warrenton','Inventory']        7300
# 	HoursConstraint['Warrenton','Payroll']          9388
# 	HoursConstraint['Warrenton','Hiring']           5280
# 	HoursConstraint['Warrenton','Marketing']        2960
# 	HoursConstraint['Warrenton','Merchandising']    1050
# 	TotalCost                                     789880
#
# Coefficients of x['Dinwiddie_County','Staunton']:
# 	AssignEachStoreOnce['Dinwiddie_County']           1
# 	HoursConstraint['Staunton','Inventory']        7300
# 	HoursConstraint['Staunton','Payroll']          9388
# 	HoursConstraint['Staunton','Hiring']           5280
# 	HoursConstraint['Staunton','Marketing']        2960
# 	HoursConstraint['Staunton','Merchandising']    1050
# 	TotalCost                                    789880
#
# Coefficients of x['Essex_County','Richmond']:
# 	AssignEachStoreOnce['Essex_County']             1
# 	HoursConstraint['Richmond','Inventory']        85
# 	HoursConstraint['Richmond','Payroll']          66
# 	HoursConstraint['Richmond','Hiring']          728
# 	HoursConstraint['Richmond','Marketing']       250
# 	HoursConstraint['Richmond','Merchandising']    82
# 	TotalCost                                    8359.78
#
# Coefficients of x['Essex_County','Tappahannock']:
# 	AssignEachStoreOnce['Essex_County']                1
# 	HoursConstraint['Tappahannock','Inventory']       63
# 	HoursConstraint['Tappahannock','Payroll']         30
# 	HoursConstraint['Tappahannock','Hiring']         680
# 	HoursConstraint['Tappahannock','Marketing']      200
# 	HoursConstraint['Tappahannock','Merchandising']   80
#
# Coefficients of x['Essex_County','Warrenton']:
# 	AssignEachStoreOnce['Essex_County']               1
# 	HoursConstraint['Warrenton','Inventory']        105.9
# 	HoursConstraint['Warrenton','Payroll']          100.2
# 	HoursConstraint['Warrenton','Hiring']           773.6
# 	HoursConstraint['Warrenton','Marketing']        297.5
# 	HoursConstraint['Warrenton','Merchandising']     83.9
# 	TotalCost                                     16236.9
#
# Coefficients of x['Essex_County','Staunton']:
# 	AssignEachStoreOnce['Essex_County']               1
# 	HoursConstraint['Staunton','Inventory']        2263
# 	HoursConstraint['Staunton','Payroll']          3630
# 	HoursConstraint['Staunton','Hiring']           5480
# 	HoursConstraint['Staunton','Marketing']        5200
# 	HoursConstraint['Staunton','Merchandising']     280
# 	TotalCost                                    503230
#
# Coefficients of x['Fauquier_County','Richmond']:
# 	AssignEachStoreOnce['Fauquier_County']             1
# 	HoursConstraint['Richmond','Inventory']         4455
# 	HoursConstraint['Richmond','Payroll']           7428
# 	HoursConstraint['Richmond','Hiring']            8280
# 	HoursConstraint['Richmond','Marketing']         4120
# 	HoursConstraint['Richmond','Merchandising']     8840
# 	TotalCost                                    1025570
#
# Coefficients of x['Fauquier_County','Tappahannock']:
# 	AssignEachStoreOnce['Fauquier_County']               1
# 	HoursConstraint['Tappahannock','Inventory']        141.24
# 	HoursConstraint['Tappahannock','Payroll']          369.12
# 	HoursConstraint['Tappahannock','Hiring']           436.8
# 	HoursConstraint['Tappahannock','Marketing']        394.48
# 	HoursConstraint['Tappahannock','Merchandising']    212.48
# 	TotalCost                                        33174.1
#
# Coefficients of x['Fauquier_County','Warrenton']:
# 	AssignEachStoreOnce['Fauquier_County']          1
# 	HoursConstraint['Warrenton','Inventory']       55
# 	HoursConstraint['Warrenton','Payroll']        228
# 	HoursConstraint['Warrenton','Hiring']         280
# 	HoursConstraint['Warrenton','Marketing']      320
# 	HoursConstraint['Warrenton','Merchandising']   40
#
# Coefficients of x['Fauquier_County','Staunton']:
# 	AssignEachStoreOnce['Fauquier_County']           1
# 	HoursConstraint['Staunton','Inventory']        142.12
# 	HoursConstraint['Staunton','Payroll']          370.56
# 	HoursConstraint['Staunton','Hiring']           438.4
# 	HoursConstraint['Staunton','Marketing']        395.24
# 	HoursConstraint['Staunton','Merchandising']    214.24
# 	TotalCost                                    38804.2
#
# Coefficients of x['Fluvanna_County','Richmond']:
# 	AssignEachStoreOnce['Fluvanna_County']      1
# 	HoursConstraint['Richmond','Inventory']     4
# 	HoursConstraint['Richmond','Payroll']     148.8
# 	HoursConstraint['Richmond','Marketing']    10.2
# 	TotalCost                                3302
#
# Coefficients of x['Fluvanna_County','Tappahannock']:
# 	AssignEachStoreOnce['Fluvanna_County']          1
# 	HoursConstraint['Tappahannock','Inventory']     4
# 	HoursConstraint['Tappahannock','Payroll']     186.24
# 	HoursConstraint['Tappahannock','Marketing']    11.76
# 	TotalCost                                    5486
#
# Coefficients of x['Fluvanna_County','Warrenton']:
# 	AssignEachStoreOnce['Fluvanna_County']       1
# 	HoursConstraint['Warrenton','Inventory']     4
# 	HoursConstraint['Warrenton','Payroll']     175.2
# 	HoursConstraint['Warrenton','Marketing']    11.3
# 	TotalCost                                 4280.25
#
# Coefficients of x['Fluvanna_County','Staunton']:
# 	AssignEachStoreOnce['Fluvanna_County']      1
# 	HoursConstraint['Staunton','Inventory']     4
# 	HoursConstraint['Staunton','Payroll']     144
# 	HoursConstraint['Staunton','Marketing']    10
# 	TotalCost                                3025.75
#
# Coefficients of x['Goochland_County','Richmond']:
# 	AssignEachStoreOnce['Goochland_County']         1
# 	HoursConstraint['Richmond','Inventory']        13.26
# 	HoursConstraint['Richmond','Payroll']         139.84
# 	HoursConstraint['Richmond','Marketing']        86.38
# 	HoursConstraint['Richmond','Merchandising']     7.52
# 	TotalCost                                    3510
#
# Coefficients of x['Goochland_County','Tappahannock']:
# 	AssignEachStoreOnce['Goochland_County']             1
# 	HoursConstraint['Tappahannock','Inventory']        14.84
# 	HoursConstraint['Tappahannock','Payroll']         193.56
# 	HoursConstraint['Tappahannock','Marketing']       106.92
# 	HoursConstraint['Tappahannock','Merchandising']    10.68
# 	TotalCost                                        7904
#
# Coefficients of x['Goochland_County','Warrenton']:
# 	AssignEachStoreOnce['Goochland_County']           1
# 	HoursConstraint['Warrenton','Inventory']         15.86
# 	HoursConstraint['Warrenton','Payroll']          228.24
# 	HoursConstraint['Warrenton','Marketing']        120.18
# 	HoursConstraint['Warrenton','Merchandising']     12.72
# 	TotalCost                                     10049
#
# Coefficients of x['Goochland_County','Staunton']:
# 	AssignEachStoreOnce['Goochland_County']         1
# 	HoursConstraint['Staunton','Inventory']        14.74
# 	HoursConstraint['Staunton','Payroll']         190.16
# 	HoursConstraint['Staunton','Marketing']       105.62
# 	HoursConstraint['Staunton','Merchandising']    10.48
# 	TotalCost                                    8300.5
#
# Coefficients of x['Greene_County','Richmond']:
# 	AssignEachStoreOnce['Greene_County']            1
# 	HoursConstraint['Richmond','Inventory']        51.7
# 	HoursConstraint['Richmond','Payroll']         122.54
# 	HoursConstraint['Richmond','Hiring']          168.84
# 	HoursConstraint['Richmond','Merchandising']    46.28
# 	TotalCost                                    4374.24
#
# Coefficients of x['Greene_County','Tappahannock']:
# 	AssignEachStoreOnce['Greene_County']                1
# 	HoursConstraint['Tappahannock','Inventory']        59.8
# 	HoursConstraint['Tappahannock','Payroll']         140.36
# 	HoursConstraint['Tappahannock','Hiring']          178.56
# 	HoursConstraint['Tappahannock','Merchandising']    49.52
# 	TotalCost                                        6171.36
#
# Coefficients of x['Greene_County','Warrenton']:
# 	AssignEachStoreOnce['Greene_County']             1
# 	HoursConstraint['Warrenton','Inventory']        48.1
# 	HoursConstraint['Warrenton','Payroll']         114.62
# 	HoursConstraint['Warrenton','Hiring']          164.52
# 	HoursConstraint['Warrenton','Merchandising']    44.84
# 	TotalCost                                     3082.56
#
# Coefficients of x['Greene_County','Staunton']:
# 	AssignEachStoreOnce['Greene_County']            1
# 	HoursConstraint['Staunton','Inventory']        47.7
# 	HoursConstraint['Staunton','Payroll']         113.74
# 	HoursConstraint['Staunton','Hiring']          164.04
# 	HoursConstraint['Staunton','Merchandising']    44.68
# 	TotalCost                                    3116.88
#
# Coefficients of x['Hanover_County','Richmond']:
# 	AssignEachStoreOnce['Hanover_County']           1
# 	HoursConstraint['Richmond','Payroll']         204.7
# 	HoursConstraint['Richmond','Hiring']          155.4
# 	HoursConstraint['Richmond','Marketing']       218
# 	HoursConstraint['Richmond','Merchandising']   125.4
# 	TotalCost                                    2831.4
#
# Coefficients of x['Hanover_County','Tappahannock']:
# 	AssignEachStoreOnce['Hanover_County']               1
# 	HoursConstraint['Tappahannock','Payroll']         224.02
# 	HoursConstraint['Tappahannock','Hiring']          160.44
# 	HoursConstraint['Tappahannock','Marketing']       234.8
# 	HoursConstraint['Tappahannock','Merchandising']   130.44
# 	TotalCost                                        5190.9
#
# Coefficients of x['Hanover_County','Warrenton']:
# 	AssignEachStoreOnce['Hanover_County']            1
# 	HoursConstraint['Warrenton','Payroll']         256.68
# 	HoursConstraint['Warrenton','Hiring']          168.96
# 	HoursConstraint['Warrenton','Marketing']       263.2
# 	HoursConstraint['Warrenton','Merchandising']   138.96
# 	TotalCost                                     9795.5
#
# Coefficients of x['Hanover_County','Staunton']:
# 	AssignEachStoreOnce['Hanover_County']            1
# 	HoursConstraint['Staunton','Payroll']          270.02
# 	HoursConstraint['Staunton','Hiring']           172.44
# 	HoursConstraint['Staunton','Marketing']        274.8
# 	HoursConstraint['Staunton','Merchandising']    142.44
# 	TotalCost                                    12748.5
#
# Coefficients of x['Henrico_County','Richmond']:
# 	AssignEachStoreOnce['Henrico_County']          1
# 	HoursConstraint['Richmond','Inventory']       96
# 	HoursConstraint['Richmond','Payroll']        227
# 	HoursConstraint['Richmond','Marketing']       84
# 	HoursConstraint['Richmond','Merchandising']   78
#
# Coefficients of x['Henrico_County','Tappahannock']:
# 	AssignEachStoreOnce['Henrico_County']                 1
# 	HoursConstraint['Tappahannock','Inventory']        2696
# 	HoursConstraint['Tappahannock','Payroll']         14427
# 	HoursConstraint['Tappahannock','Marketing']        3284
# 	HoursConstraint['Tappahannock','Merchandising']     878
# 	TotalCost                                        662480
#
# Coefficients of x['Henrico_County','Warrenton']:
# 	AssignEachStoreOnce['Henrico_County']             1
# 	HoursConstraint['Warrenton','Inventory']        141.5
# 	HoursConstraint['Warrenton','Payroll']          475.5
# 	HoursConstraint['Warrenton','Marketing']        140
# 	HoursConstraint['Warrenton','Merchandising']     92
# 	TotalCost                                     20780.2
#
# Coefficients of x['Henrico_County','Staunton']:
# 	AssignEachStoreOnce['Henrico_County']             1
# 	HoursConstraint['Staunton','Inventory']        2696
# 	HoursConstraint['Staunton','Payroll']         14427
# 	HoursConstraint['Staunton','Marketing']        3284
# 	HoursConstraint['Staunton','Merchandising']     878
# 	TotalCost                                    662480
#
# Coefficients of x['Hopewell_County','Richmond']:
# 	AssignEachStoreOnce['Hopewell_County']         1
# 	HoursConstraint['Richmond','Inventory']        8
# 	HoursConstraint['Richmond','Payroll']         42
# 	HoursConstraint['Richmond','Merchandising']    6
# 	TotalCost                                    465.66
#
# Coefficients of x['Hopewell_County','Tappahannock']:
# 	AssignEachStoreOnce['Hopewell_County']              1
# 	HoursConstraint['Tappahannock','Inventory']         9.5
# 	HoursConstraint['Tappahannock','Payroll']          51
# 	HoursConstraint['Tappahannock','Merchandising']     9
# 	TotalCost                                        1258.92
#
# Coefficients of x['Hopewell_County','Warrenton']:
# 	AssignEachStoreOnce['Hopewell_County']            1
# 	HoursConstraint['Warrenton','Inventory']        207
# 	HoursConstraint['Warrenton','Payroll']         1236
# 	HoursConstraint['Warrenton','Merchandising']    404
# 	TotalCost                                     57330
#
# Coefficients of x['Hopewell_County','Staunton']:
# 	AssignEachStoreOnce['Hopewell_County']           1
# 	HoursConstraint['Staunton','Inventory']        207
# 	HoursConstraint['Staunton','Payroll']         1236
# 	HoursConstraint['Staunton','Merchandising']    404
# 	TotalCost                                    57330
#
# Coefficients of x['James_City_County','Richmond']:
# 	AssignEachStoreOnce['James_City_County']        1
# 	HoursConstraint['Richmond','Inventory']       402.8
# 	HoursConstraint['Richmond','Payroll']         200.92
# 	HoursConstraint['Richmond','Hiring']           63.52
# 	HoursConstraint['Richmond','Merchandising']   155.84
# 	TotalCost                                    8847.8
#
# Coefficients of x['James_City_County','Tappahannock']:
# 	AssignEachStoreOnce['James_City_County']             1
# 	HoursConstraint['Tappahannock','Inventory']        435.2
# 	HoursConstraint['Tappahannock','Payroll']          246.28
# 	HoursConstraint['Tappahannock','Hiring']            65.68
# 	HoursConstraint['Tappahannock','Merchandising']    165.56
# 	TotalCost                                        13120.6
#
# Coefficients of x['James_City_County','Warrenton']:
# 	AssignEachStoreOnce['James_City_County']           1
# 	HoursConstraint['Warrenton','Inventory']        6350
# 	HoursConstraint['Warrenton','Payroll']          8527
# 	HoursConstraint['Warrenton','Hiring']            460
# 	HoursConstraint['Warrenton','Merchandising']    1940
# 	TotalCost                                     528710
#
# Coefficients of x['James_City_County','Staunton']:
# 	AssignEachStoreOnce['James_City_County']          1
# 	HoursConstraint['Staunton','Inventory']        6350
# 	HoursConstraint['Staunton','Payroll']          8527
# 	HoursConstraint['Staunton','Hiring']            460
# 	HoursConstraint['Staunton','Merchandising']    1940
# 	TotalCost                                    528710
#
# Coefficients of x['King_and_Queen_County','Richmond']:
# 	AssignEachStoreOnce['King_and_Queen_County']     1
# 	HoursConstraint['Richmond','Inventory']         28.88
# 	HoursConstraint['Richmond','Payroll']           25.64
# 	HoursConstraint['Richmond','Hiring']           363.28
# 	HoursConstraint['Richmond','Marketing']         59.4
# 	HoursConstraint['Richmond','Merchandising']     63.88
# 	TotalCost                                     3224
#
# Coefficients of x['King_and_Queen_County','Tappahannock']:
# 	AssignEachStoreOnce['King_and_Queen_County']        1
# 	HoursConstraint['Tappahannock','Inventory']        26.68
# 	HoursConstraint['Tappahannock','Payroll']          19.04
# 	HoursConstraint['Tappahannock','Hiring']          350.08
# 	HoursConstraint['Tappahannock','Marketing']        48.4
# 	HoursConstraint['Tappahannock','Merchandising']    61.68
# 	TotalCost                                        1410.24
#
# Coefficients of x['King_and_Queen_County','Warrenton']:
# 	AssignEachStoreOnce['King_and_Queen_County']     1
# 	HoursConstraint['Warrenton','Inventory']        34
# 	HoursConstraint['Warrenton','Payroll']          41
# 	HoursConstraint['Warrenton','Hiring']          394
# 	HoursConstraint['Warrenton','Marketing']        85
# 	HoursConstraint['Warrenton','Merchandising']    69
# 	TotalCost                                     7824.96
#
# Coefficients of x['King_and_Queen_County','Staunton']:
# 	AssignEachStoreOnce['King_and_Queen_County']       1
# 	HoursConstraint['Staunton','Inventory']          425
# 	HoursConstraint['Staunton','Payroll']           1214
# 	HoursConstraint['Staunton','Hiring']            2740
# 	HoursConstraint['Staunton','Marketing']         2040
# 	HoursConstraint['Staunton','Merchandising']      460
# 	TotalCost                                     203840
#
# Coefficients of x['King_George_County','Richmond']:
# 	AssignEachStoreOnce['King_George_County']       1
# 	HoursConstraint['Richmond','Inventory']        23.32
# 	HoursConstraint['Richmond','Payroll']          73.08
# 	HoursConstraint['Richmond','Hiring']          164.64
# 	HoursConstraint['Richmond','Merchandising']    79.76
# 	TotalCost                                    2719.6
#
# Coefficients of x['King_George_County','Tappahannock']:
# 	AssignEachStoreOnce['King_George_County']           1
# 	HoursConstraint['Tappahannock','Inventory']        20.38
# 	HoursConstraint['Tappahannock','Payroll']          66.22
# 	HoursConstraint['Tappahannock','Hiring']          158.76
# 	HoursConstraint['Tappahannock','Merchandising']    75.84
# 	TotalCost                                        1601.6
#
# Coefficients of x['King_George_County','Warrenton']:
# 	AssignEachStoreOnce['King_George_County']        1
# 	HoursConstraint['Warrenton','Inventory']        23.98
# 	HoursConstraint['Warrenton','Payroll']          74.62
# 	HoursConstraint['Warrenton','Hiring']          165.96
# 	HoursConstraint['Warrenton','Merchandising']    80.64
# 	TotalCost                                     2740.4
#
# Coefficients of x['King_George_County','Staunton']:
# 	AssignEachStoreOnce['King_George_County']         1
# 	HoursConstraint['Staunton','Inventory']         616
# 	HoursConstraint['Staunton','Payroll']          1456
# 	HoursConstraint['Staunton','Hiring']           1350
# 	HoursConstraint['Staunton','Merchandising']     870
# 	TotalCost                                    127400
#
# Coefficients of x['King_William_County','Richmond']:
# 	AssignEachStoreOnce['King_William_County']      1
# 	HoursConstraint['Richmond','Inventory']        37.5
# 	HoursConstraint['Richmond','Payroll']          91
# 	HoursConstraint['Richmond','Hiring']           63
# 	HoursConstraint['Richmond','Marketing']        55
# 	HoursConstraint['Richmond','Merchandising']    63
# 	TotalCost                                    2522.52
#
# Coefficients of x['King_William_County','Tappahannock']:
# 	AssignEachStoreOnce['King_William_County']          1
# 	HoursConstraint['Tappahannock','Inventory']        35.5
# 	HoursConstraint['Tappahannock','Payroll']          85.4
# 	HoursConstraint['Tappahannock','Hiring']           62.2
# 	HoursConstraint['Tappahannock','Marketing']        51
# 	HoursConstraint['Tappahannock','Merchandising']    62.2
# 	TotalCost                                        1909.05
#
# Coefficients of x['King_William_County','Warrenton']:
# 	AssignEachStoreOnce['King_William_County']       1
# 	HoursConstraint['Warrenton','Inventory']        50.1
# 	HoursConstraint['Warrenton','Payroll']         126.28
# 	HoursConstraint['Warrenton','Hiring']           68.04
# 	HoursConstraint['Warrenton','Marketing']        80.2
# 	HoursConstraint['Warrenton','Merchandising']    68.04
# 	TotalCost                                     7232.94
#
# Coefficients of x['King_William_County','Staunton']:
# 	AssignEachStoreOnce['King_William_County']        1
# 	HoursConstraint['Staunton','Inventory']        1030
# 	HoursConstraint['Staunton','Payroll']          2870
# 	HoursConstraint['Staunton','Hiring']            460
# 	HoursConstraint['Staunton','Marketing']        2040
# 	HoursConstraint['Staunton','Merchandising']     460
# 	TotalCost                                    210210
#
# Coefficients of x['Louisa_County','Richmond']:
# 	AssignEachStoreOnce['Louisa_County']            1
# 	HoursConstraint['Richmond','Inventory']       303.6
# 	HoursConstraint['Richmond','Payroll']         202.2
# 	HoursConstraint['Richmond','Marketing']        10.1
# 	HoursConstraint['Richmond','Merchandising']    27.1
# 	TotalCost                                    7137
#
# Coefficients of x['Louisa_County','Tappahannock']:
# 	AssignEachStoreOnce['Louisa_County']                 1
# 	HoursConstraint['Tappahannock','Inventory']        329.2
# 	HoursConstraint['Tappahannock','Payroll']          269.4
# 	HoursConstraint['Tappahannock','Marketing']         11.7
# 	HoursConstraint['Tappahannock','Merchandising']     28.7
# 	TotalCost                                        12441
#
# Coefficients of x['Louisa_County','Warrenton']:
# 	AssignEachStoreOnce['Louisa_County']             1
# 	HoursConstraint['Warrenton','Inventory']       312.24
# 	HoursConstraint['Warrenton','Payroll']         224.88
# 	HoursConstraint['Warrenton','Marketing']        10.64
# 	HoursConstraint['Warrenton','Merchandising']    27.64
# 	TotalCost                                     8190
#
# Coefficients of x['Louisa_County','Staunton']:
# 	AssignEachStoreOnce['Louisa_County']              1
# 	HoursConstraint['Staunton','Inventory']        3470
# 	HoursConstraint['Staunton','Payroll']          8514
# 	HoursConstraint['Staunton','Marketing']         208
# 	HoursConstraint['Staunton','Merchandising']     225
# 	TotalCost                                    382200
#
# Coefficients of x['Madison_County','Richmond']:
# 	AssignEachStoreOnce['Madison_County']           1
# 	HoursConstraint['Richmond','Inventory']        37.1
# 	HoursConstraint['Richmond','Payroll']          44.88
# 	HoursConstraint['Richmond','Hiring']          169.32
# 	HoursConstraint['Richmond','Merchandising']    52.88
# 	TotalCost                                    3502.46
#
# Coefficients of x['Madison_County','Tappahannock']:
# 	AssignEachStoreOnce['Madison_County']               1
# 	HoursConstraint['Tappahannock','Inventory']        42.8
# 	HoursConstraint['Tappahannock','Payroll']          49.44
# 	HoursConstraint['Tappahannock','Hiring']          176.16
# 	HoursConstraint['Tappahannock','Merchandising']    57.44
# 	TotalCost                                        4421.3
#
# Coefficients of x['Madison_County','Warrenton']:
# 	AssignEachStoreOnce['Madison_County']            1
# 	HoursConstraint['Warrenton','Inventory']        30.2
# 	HoursConstraint['Warrenton','Payroll']          39.36
# 	HoursConstraint['Warrenton','Hiring']          161.04
# 	HoursConstraint['Warrenton','Merchandising']    47.36
# 	TotalCost                                     1842.62
#
# Coefficients of x['Madison_County','Staunton']:
# 	AssignEachStoreOnce['Madison_County']           1
# 	HoursConstraint['Staunton','Inventory']        32.6
# 	HoursConstraint['Staunton','Payroll']          41.28
# 	HoursConstraint['Staunton','Hiring']          163.92
# 	HoursConstraint['Staunton','Merchandising']    49.28
# 	TotalCost                                    2546.57
#
# Coefficients of x['Mathews_County','Richmond']:
# 	AssignEachStoreOnce['Mathews_County']           1
# 	HoursConstraint['Richmond','Inventory']       238
# 	HoursConstraint['Richmond','Payroll']          51
# 	HoursConstraint['Richmond','Marketing']        25
# 	HoursConstraint['Richmond','Merchandising']    78
# 	TotalCost                                    4412.07
#
# Coefficients of x['Mathews_County','Tappahannock']:
# 	AssignEachStoreOnce['Mathews_County']               1
# 	HoursConstraint['Tappahannock','Inventory']       233.56
# 	HoursConstraint['Tappahannock','Payroll']          43.6
# 	HoursConstraint['Tappahannock','Marketing']        21.3
# 	HoursConstraint['Tappahannock','Merchandising']    73.56
# 	TotalCost                                        3260.79
#
# Coefficients of x['Mathews_County','Warrenton']:
# 	AssignEachStoreOnce['Mathews_County']              1
# 	HoursConstraint['Warrenton','Inventory']        1420
# 	HoursConstraint['Warrenton','Payroll']          2021
# 	HoursConstraint['Warrenton','Marketing']        1010
# 	HoursConstraint['Warrenton','Merchandising']    1260
# 	TotalCost                                     171990
#
# Coefficients of x['Mathews_County','Staunton']:
# 	AssignEachStoreOnce['Mathews_County']             1
# 	HoursConstraint['Staunton','Inventory']        1420
# 	HoursConstraint['Staunton','Payroll']          2021
# 	HoursConstraint['Staunton','Marketing']        1010
# 	HoursConstraint['Staunton','Merchandising']    1260
# 	TotalCost                                    171990
#
# Coefficients of x['Nelson_County','Richmond']:
# 	AssignEachStoreOnce['Nelson_County']        1
# 	HoursConstraint['Richmond','Inventory']    22.4
# 	HoursConstraint['Richmond','Payroll']     180.2
# 	HoursConstraint['Richmond','Marketing']    12.2
# 	TotalCost                                6627.66
#
# Coefficients of x['Nelson_County','Tappahannock']:
# 	AssignEachStoreOnce['Nelson_County']              1
# 	HoursConstraint['Tappahannock','Inventory']     414
# 	HoursConstraint['Tappahannock','Payroll']      5271
# 	HoursConstraint['Tappahannock','Marketing']     208
# 	TotalCost                                    184730
#
# Coefficients of x['Nelson_County','Warrenton']:
# 	AssignEachStoreOnce['Nelson_County']         1
# 	HoursConstraint['Warrenton','Inventory']    22.44
# 	HoursConstraint['Warrenton','Payroll']     180.72
# 	HoursConstraint['Warrenton','Marketing']    12.22
# 	TotalCost                                 6574.88
#
# Coefficients of x['Nelson_County','Staunton']:
# 	AssignEachStoreOnce['Nelson_County']        1
# 	HoursConstraint['Staunton','Inventory']    16.92
# 	HoursConstraint['Staunton','Payroll']     108.96
# 	HoursConstraint['Staunton','Marketing']     9.46
# 	TotalCost                                2390.18
#
# Coefficients of x['New_Kent_County','Richmond']:
# 	AssignEachStoreOnce['New_Kent_County']          1
# 	HoursConstraint['Richmond','Inventory']        18.3
# 	HoursConstraint['Richmond','Payroll']          76.2
# 	HoursConstraint['Richmond','Hiring']           62.2
# 	HoursConstraint['Richmond','Marketing']       227.5
# 	HoursConstraint['Richmond','Merchandising']    64.4
# 	TotalCost                                    3501.68
#
# Coefficients of x['New_Kent_County','Tappahannock']:
# 	AssignEachStoreOnce['New_Kent_County']              1
# 	HoursConstraint['Tappahannock','Inventory']        21.78
# 	HoursConstraint['Tappahannock','Payroll']         101.72
# 	HoursConstraint['Tappahannock','Hiring']           64.52
# 	HoursConstraint['Tappahannock','Marketing']       256.5
# 	HoursConstraint['Tappahannock','Merchandising']    69.04
# 	TotalCost                                        6828.64
#
# Coefficients of x['New_Kent_County','Warrenton']:
# 	AssignEachStoreOnce['New_Kent_County']             1
# 	HoursConstraint['Warrenton','Inventory']         615
# 	HoursConstraint['Warrenton','Payroll']          4452
# 	HoursConstraint['Warrenton','Hiring']            460
# 	HoursConstraint['Warrenton','Marketing']        5200
# 	HoursConstraint['Warrenton','Merchandising']     860
# 	TotalCost                                     356720
#
# Coefficients of x['New_Kent_County','Staunton']:
# 	AssignEachStoreOnce['New_Kent_County']            1
# 	HoursConstraint['Staunton','Inventory']         615
# 	HoursConstraint['Staunton','Payroll']          4452
# 	HoursConstraint['Staunton','Hiring']            460
# 	HoursConstraint['Staunton','Marketing']        5200
# 	HoursConstraint['Staunton','Merchandising']     860
# 	TotalCost                                    356720
#
# Coefficients of x['Orange_County','Richmond']:
# 	AssignEachStoreOnce['Orange_County']            1
# 	HoursConstraint['Richmond','Inventory']        48.6
# 	HoursConstraint['Richmond','Payroll']         181.9
# 	HoursConstraint['Richmond','Hiring']          166.2
# 	HoursConstraint['Richmond','Merchandising']    30.4
# 	TotalCost                                    5250.96
#
# Coefficients of x['Orange_County','Tappahannock']:
# 	AssignEachStoreOnce['Orange_County']                1
# 	HoursConstraint['Tappahannock','Inventory']        56.28
# 	HoursConstraint['Tappahannock','Payroll']         198.22
# 	HoursConstraint['Tappahannock','Hiring']          171.96
# 	HoursConstraint['Tappahannock','Merchandising']    32.32
# 	TotalCost                                        6499.35
#
# Coefficients of x['Orange_County','Warrenton']:
# 	AssignEachStoreOnce['Orange_County']             1
# 	HoursConstraint['Warrenton','Inventory']        43
# 	HoursConstraint['Warrenton','Payroll']         170
# 	HoursConstraint['Warrenton','Hiring']          162
# 	HoursConstraint['Warrenton','Merchandising']    29
# 	TotalCost                                     3376.23
#
# Coefficients of x['Orange_County','Staunton']:
# 	AssignEachStoreOnce['Orange_County']            1
# 	HoursConstraint['Staunton','Inventory']        47.16
# 	HoursConstraint['Staunton','Payroll']         178.84
# 	HoursConstraint['Staunton','Hiring']          165.12
# 	HoursConstraint['Staunton','Merchandising']    30.04
# 	TotalCost                                    4942.08
#
# Coefficients of x['Page_County','Richmond']:
# 	AssignEachStoreOnce['Page_County']                1
# 	HoursConstraint['Richmond','Inventory']        1700
# 	HoursConstraint['Richmond','Payroll']          2970
# 	HoursConstraint['Richmond','Hiring']           2776
# 	HoursConstraint['Richmond','Marketing']         808
# 	HoursConstraint['Richmond','Merchandising']    3040
# 	TotalCost                                    343980
#
# Coefficients of x['Page_County','Tappahannock']:
# 	AssignEachStoreOnce['Page_County']                    1
# 	HoursConstraint['Tappahannock','Inventory']        1700
# 	HoursConstraint['Tappahannock','Payroll']          2970
# 	HoursConstraint['Tappahannock','Hiring']           2776
# 	HoursConstraint['Tappahannock','Marketing']         808
# 	HoursConstraint['Tappahannock','Merchandising']    3040
# 	TotalCost                                        343980
#
# Coefficients of x['Page_County','Warrenton']:
# 	AssignEachStoreOnce['Page_County']               1
# 	HoursConstraint['Warrenton','Inventory']       116.8
# 	HoursConstraint['Warrenton','Payroll']         199.4
# 	HoursConstraint['Warrenton','Hiring']          203.3
# 	HoursConstraint['Warrenton','Marketing']        16.4
# 	HoursConstraint['Warrenton','Merchandising']    71.5
# 	TotalCost                                     5728.32
#
# Coefficients of x['Page_County','Staunton']:
# 	AssignEachStoreOnce['Page_County']              1
# 	HoursConstraint['Staunton','Inventory']       116.96
# 	HoursConstraint['Staunton','Payroll']         199.68
# 	HoursConstraint['Staunton','Hiring']          203.56
# 	HoursConstraint['Staunton','Marketing']        16.48
# 	HoursConstraint['Staunton','Merchandising']    71.8
# 	TotalCost                                    6577.74
#
# Coefficients of x['Powhatan_County','Richmond']:
# 	AssignEachStoreOnce['Powhatan_County']      1
# 	HoursConstraint['Richmond','Inventory']    17.5
# 	HoursConstraint['Richmond','Payroll']     193
# 	HoursConstraint['Richmond','Hiring']       66
# 	HoursConstraint['Richmond','Marketing']    25
# 	TotalCost                                2914.86
#
# Coefficients of x['Powhatan_County','Tappahannock']:
# 	AssignEachStoreOnce['Powhatan_County']          1
# ...
# 	55.72*x['Buckingham_County','Warrenton'] +
# 	24.6*x['Caroline_County','Warrenton'] +
# 	5690*x['Charles_City_County','Warrenton'] +
# 	883.8*x['Chesterfield_County','Warrenton'] +
# 	159.48*x['City_of_Fredericksburg','Warrenton'] +
# 	619.7*x['City_of_Richmond','Warrenton'] +
# 	16.8*x['Culpeper_County','Warrenton'] +
# 	55.02*x['Cumberland_County','Warrenton'] +
# 	7300*x['Dinwiddie_County','Warrenton'] +
# 	105.9*x['Essex_County','Warrenton'] +
# 	55*x['Fauquier_County','Warrenton'] +
# 	4*x['Fluvanna_County','Warrenton'] +
# 	15.86*x['Goochland_County','Warrenton'] +
# 	48.1*x['Greene_County','Warrenton'] +
# 	141.5*x['Henrico_County','Warrenton'] +
# 	207*x['Hopewell_County','Warrenton'] +
# 	6350*x['James_City_County','Warrenton'] +
# 	34*x['King_and_Queen_County','Warrenton'] +
# 	23.98*x['King_George_County','Warrenton'] +
# 	50.1*x['King_William_County','Warrenton'] +
# 	312.24*x['Louisa_County','Warrenton'] +
# 	30.2*x['Madison_County','Warrenton'] +
# 	1420*x['Mathews_County','Warrenton'] +
# 	22.44*x['Nelson_County','Warrenton'] +
# 	615*x['New_Kent_County','Warrenton'] +
# 	43*x['Orange_County','Warrenton'] + 116.8*x['Page_County','Warrenton']
# 	 + 20.5*x['Powhatan_County','Warrenton'] +
# 	208*x['Prince_George_County','Warrenton'] +
# 	381.88*x['Prince_William_County','Warrenton'] +
# 	14701*x['Rockbridge_County','Warrenton'] +
# 	751.8*x['Rockingham_County','Warrenton'] +
# 	116.48*x['Shenandoah_County','Warrenton'] +
# 	12.52*x['Spotsylvania_County','Warrenton'] +
# 	23.68*x['Stafford_County','Warrenton'] +
# 	26*x['Warren_County','Warrenton'] +
# 	157.36*x['Westmoreland_County','Warrenton'] +
# 	1230*x['York_County','Warrenton'] <= 825;
#
# subject to HoursConstraint['Warrenton','Payroll']:
# 	1185.96*x['Albemarle_County','Warrenton'] +
# 	2228*x['Amherst_County','Warrenton'] +
# 	1111.92*x['Augusta_County','Warrenton'] +
# 	49.72*x['Buckingham_County','Warrenton'] +
# 	185.3*x['Caroline_County','Warrenton'] +
# 	1226*x['Charles_City_County','Warrenton'] +
# 	675.8*x['Chesterfield_County','Warrenton'] +
# 	79.36*x['City_of_Fredericksburg','Warrenton'] +
# 	523*x['City_of_Richmond','Warrenton'] +
# 	110.4*x['Culpeper_County','Warrenton'] +
# 	71.88*x['Cumberland_County','Warrenton'] +
# 	9388*x['Dinwiddie_County','Warrenton'] +
# 	100.2*x['Essex_County','Warrenton'] +
# 	228*x['Fauquier_County','Warrenton'] +
# 	175.2*x['Fluvanna_County','Warrenton'] +
# 	228.24*x['Goochland_County','Warrenton'] +
# 	114.62*x['Greene_County','Warrenton'] +
# 	256.68*x['Hanover_County','Warrenton'] +
# 	475.5*x['Henrico_County','Warrenton'] +
# 	1236*x['Hopewell_County','Warrenton'] +
# 	8527*x['James_City_County','Warrenton'] +
# 	41*x['King_and_Queen_County','Warrenton'] +
# 	74.62*x['King_George_County','Warrenton'] +
# 	126.28*x['King_William_County','Warrenton'] +
# 	224.88*x['Louisa_County','Warrenton'] +
# 	39.36*x['Madison_County','Warrenton'] +
# 	2021*x['Mathews_County','Warrenton'] +
# 	180.72*x['Nelson_County','Warrenton'] +
# 	4452*x['New_Kent_County','Warrenton'] +
# 	170*x['Orange_County','Warrenton'] + 199.4*x['Page_County','Warrenton']
# 	 + 283*x['Powhatan_County','Warrenton'] +
# 	1424*x['Prince_George_County','Warrenton'] +
# 	454.6*x['Prince_William_County','Warrenton'] +
# 	9*x['Rappahannock_County','Warrenton'] +
# 	9670*x['Rockbridge_County','Warrenton'] +
# 	985.4*x['Rockingham_County','Warrenton'] +
# 	115.54*x['Shenandoah_County','Warrenton'] +
# 	246.24*x['Spotsylvania_County','Warrenton'] +
# 	248*x['Stafford_County','Warrenton'] +
# 	131.5*x['Warren_County','Warrenton'] +
# 	46.92*x['Westmoreland_County','Warrenton'] +
# 	8091*x['York_County','Warrenton'] <= 2500;
#
# subject to HoursConstraint['Warrenton','Hiring']:
# 	3572.32*x['Augusta_County','Warrenton'] +
# 	519.78*x['Buckingham_County','Warrenton'] +
# 	187.4*x['Caroline_County','Warrenton'] +
# 	29.48*x['Chesterfield_County','Warrenton'] +
# 	63.84*x['City_of_Fredericksburg','Warrenton'] +
# 	209.6*x['Culpeper_County','Warrenton'] +
# 	92.34*x['Cumberland_County','Warrenton'] +
# 	5280*x['Dinwiddie_County','Warrenton'] +
# 	773.6*x['Essex_County','Warrenton'] +
# 	280*x['Fauquier_County','Warrenton'] +
# 	164.52*x['Greene_County','Warrenton'] +
# 	168.96*x['Hanover_County','Warrenton'] +
# 	460*x['James_City_County','Warrenton'] +
# 	394*x['King_and_Queen_County','Warrenton'] +
# 	165.96*x['King_George_County','Warrenton'] +
# 	68.04*x['King_William_County','Warrenton'] +
# 	161.04*x['Madison_County','Warrenton'] +
# 	460*x['New_Kent_County','Warrenton'] +
# 	162*x['Orange_County','Warrenton'] + 203.3*x['Page_County','Warrenton']
# 	 + 78*x['Powhatan_County','Warrenton'] +
# 	860*x['Prince_George_County','Warrenton'] +
# 	367.2*x['Prince_William_County','Warrenton'] +
# 	156*x['Rappahannock_County','Warrenton'] +
# 	5650*x['Rockbridge_County','Warrenton'] +
# 	4247.5*x['Rockingham_County','Warrenton'] +
# 	136.48*x['Shenandoah_County','Warrenton'] +
# 	163.56*x['Spotsylvania_County','Warrenton'] +
# 	107.68*x['Stafford_County','Warrenton'] +
# 	134.96*x['Westmoreland_County','Warrenton'] <= 3375;
#
# subject to HoursConstraint['Warrenton','Marketing']:
# 	155.28*x['Albemarle_County','Warrenton'] +
# 	208*x['Amherst_County','Warrenton'] +
# 	383.6*x['Augusta_County','Warrenton'] +
# 	156.9*x['Buckingham_County','Warrenton'] +
# 	24.5*x['Caroline_County','Warrenton'] +
# 	2040*x['Charles_City_County','Warrenton'] +
# 	193.92*x['Chesterfield_County','Warrenton'] +
# 	23.72*x['Cumberland_County','Warrenton'] +
# 	2960*x['Dinwiddie_County','Warrenton'] +
# 	297.5*x['Essex_County','Warrenton'] +
# 	320*x['Fauquier_County','Warrenton'] +
# 	11.3*x['Fluvanna_County','Warrenton'] +
# 	120.18*x['Goochland_County','Warrenton'] +
# 	263.2*x['Hanover_County','Warrenton'] +
# 	140*x['Henrico_County','Warrenton'] +
# 	85*x['King_and_Queen_County','Warrenton'] +
# 	80.2*x['King_William_County','Warrenton'] +
# 	10.64*x['Louisa_County','Warrenton'] +
# 	1010*x['Mathews_County','Warrenton'] +
# 	12.22*x['Nelson_County','Warrenton'] +
# 	5200*x['New_Kent_County','Warrenton'] +
# 	16.4*x['Page_County','Warrenton'] + 31*x['Powhatan_County','Warrenton']
# 	 + 1652*x['Prince_George_County','Warrenton'] +
# 	276.88*x['Prince_William_County','Warrenton'] +
# 	3826*x['Rockbridge_County','Warrenton'] +
# 	340.8*x['Rockingham_County','Warrenton'] +
# 	8.12*x['Shenandoah_County','Warrenton'] +
# 	3.5*x['Warren_County','Warrenton'] +
# 	28.7*x['Westmoreland_County','Warrenton'] +
# 	1010*x['York_County','Warrenton'] <= 1325;
#
# subject to HoursConstraint['Warrenton','Merchandising']:
# 	105.6*x['Albemarle_County','Warrenton'] +
# 	188.6*x['Augusta_County','Warrenton'] +
# 	78.44*x['Buckingham_County','Warrenton'] +
# 	66.6*x['Caroline_County','Warrenton'] +
# 	215*x['Charles_City_County','Warrenton'] +
# 	20.48*x['Chesterfield_County','Warrenton'] +
# 	81.52*x['City_of_Fredericksburg','Warrenton'] +
# 	5.7*x['City_of_Richmond','Warrenton'] +
# 	126*x['Culpeper_County','Warrenton'] +
# 	1050*x['Dinwiddie_County','Warrenton'] +
# 	83.9*x['Essex_County','Warrenton'] +
# 	40*x['Fauquier_County','Warrenton'] +
# 	12.72*x['Goochland_County','Warrenton'] +
# 	44.84*x['Greene_County','Warrenton'] +
# 	138.96*x['Hanover_County','Warrenton'] +
# 	92*x['Henrico_County','Warrenton'] +
# 	404*x['Hopewell_County','Warrenton'] +
# 	1940*x['James_City_County','Warrenton'] +
# 	69*x['King_and_Queen_County','Warrenton'] +
# 	80.64*x['King_George_County','Warrenton'] +
# 	68.04*x['King_William_County','Warrenton'] +
# 	27.64*x['Louisa_County','Warrenton'] +
# 	47.36*x['Madison_County','Warrenton'] +
# 	1260*x['Mathews_County','Warrenton'] +
# 	860*x['New_Kent_County','Warrenton'] +
# 	29*x['Orange_County','Warrenton'] + 71.5*x['Page_County','Warrenton']
# 	 + 372.68*x['Prince_William_County','Warrenton'] +
# 	136*x['Rappahannock_County','Warrenton'] +
# 	2428*x['Rockbridge_County','Warrenton'] +
# 	147.5*x['Rockingham_County','Warrenton'] +
# 	45.6*x['Shenandoah_County','Warrenton'] +
# 	103.56*x['Spotsylvania_County','Warrenton'] +
# 	119.6*x['Stafford_County','Warrenton'] +
# 	8*x['Warren_County','Warrenton'] +
# 	51.22*x['Westmoreland_County','Warrenton'] +
# 	1250*x['York_County','Warrenton'] <= 850;
#
# subject to HoursConstraint['Staunton','Inventory']:
# 	511.48*x['Albemarle_County','Staunton'] +
# 	2*x['Amherst_County','Staunton'] + 341*x['Augusta_County','Staunton']
# 	 + 51.2*x['Buckingham_County','Staunton'] +
# 	813*x['Caroline_County','Staunton'] +
# 	5690*x['Charles_City_County','Staunton'] +
# 	11655*x['Chesterfield_County','Staunton'] +
# 	205.84*x['City_of_Fredericksburg','Staunton'] +
# 	8668*x['City_of_Richmond','Staunton'] +
# 	24.24*x['Culpeper_County','Staunton'] +
# 	45.08*x['Cumberland_County','Staunton'] +
# 	7300*x['Dinwiddie_County','Staunton'] +
# 	2263*x['Essex_County','Staunton'] +
# 	142.12*x['Fauquier_County','Staunton'] +
# 	4*x['Fluvanna_County','Staunton'] +
# 	14.74*x['Goochland_County','Staunton'] +
# 	47.7*x['Greene_County','Staunton'] +
# 	2696*x['Henrico_County','Staunton'] +
# 	207*x['Hopewell_County','Staunton'] +
# 	6350*x['James_City_County','Staunton'] +
# 	425*x['King_and_Queen_County','Staunton'] +
# 	616*x['King_George_County','Staunton'] +
# 	1030*x['King_William_County','Staunton'] +
# 	3470*x['Louisa_County','Staunton'] +
# 	32.6*x['Madison_County','Staunton'] +
# 	1420*x['Mathews_County','Staunton'] +
# 	16.92*x['Nelson_County','Staunton'] +
# 	615*x['New_Kent_County','Staunton'] +
# 	47.16*x['Orange_County','Staunton'] +
# 	116.96*x['Page_County','Staunton'] +
# 	19.32*x['Powhatan_County','Staunton'] +
# 	208*x['Prince_George_County','Staunton'] +
# 	8932*x['Prince_William_County','Staunton'] +
# 	185.68*x['Rockbridge_County','Staunton'] +
# 	647.84*x['Rockingham_County','Staunton'] +
# 	116*x['Shenandoah_County','Staunton'] +
# 	16.2*x['Spotsylvania_County','Staunton'] +
# 	816*x['Stafford_County','Staunton'] + 50*x['Warren_County','Staunton']
# 	 + 2905*x['Westmoreland_County','Staunton'] +
# 	1230*x['York_County','Staunton'] <= 3550;
#
# subject to HoursConstraint['Staunton','Payroll']:
# 	946.56*x['Albemarle_County','Staunton'] +
# 	51.76*x['Amherst_County','Staunton'] +
# 	737*x['Augusta_County','Staunton'] +
# 	45.2*x['Buckingham_County','Staunton'] +
# 	3536*x['Caroline_County','Staunton'] +
# 	1226*x['Charles_City_County','Staunton'] +
# 	16343*x['Chesterfield_County','Staunton'] +
# 	98.88*x['City_of_Fredericksburg','Staunton'] +
# 	14264*x['City_of_Richmond','Staunton'] +
# 	132.72*x['Culpeper_County','Staunton'] +
# 	60.52*x['Cumberland_County','Staunton'] +
# 	9388*x['Dinwiddie_County','Staunton'] +
# 	3630*x['Essex_County','Staunton'] +
# 	370.56*x['Fauquier_County','Staunton'] +
# 	144*x['Fluvanna_County','Staunton'] +
# 	190.16*x['Goochland_County','Staunton'] +
# 	113.74*x['Greene_County','Staunton'] +
# 	270.02*x['Hanover_County','Staunton'] +
# 	14427*x['Henrico_County','Staunton'] +
# 	1236*x['Hopewell_County','Staunton'] +
# 	8527*x['James_City_County','Staunton'] +
# 	1214*x['King_and_Queen_County','Staunton'] +
# 	1456*x['King_George_County','Staunton'] +
# 	2870*x['King_William_County','Staunton'] +
# 	8514*x['Louisa_County','Staunton'] +
# 	41.28*x['Madison_County','Staunton'] +
# 	2021*x['Mathews_County','Staunton'] +
# 	108.96*x['Nelson_County','Staunton'] +
# 	4452*x['New_Kent_County','Staunton'] +
# 	178.84*x['Orange_County','Staunton'] +
# 	199.68*x['Page_County','Staunton'] +
# 	247.6*x['Powhatan_County','Staunton'] +
# 	1424*x['Prince_George_County','Staunton'] +
# 	12385*x['Prince_William_County','Staunton'] +
# 	11.12*x['Rappahannock_County','Staunton'] +
# 	523.36*x['Rockbridge_County','Staunton'] +
# 	831.72*x['Rockingham_County','Staunton'] +
# 	115*x['Shenandoah_County','Staunton'] +
# 	290.4*x['Spotsylvania_County','Staunton'] +
# 	5200*x['Stafford_County','Staunton'] +
# 	142*x['Warren_County','Staunton'] +
# 	1617*x['Westmoreland_County','Staunton'] +
# 	8091*x['York_County','Staunton'] <= 3450;
#
# subject to HoursConstraint['Staunton','Hiring']:
# 	2806*x['Augusta_County','Staunton'] +
# 	467.8*x['Buckingham_County','Staunton'] +
# 	1370*x['Caroline_County','Staunton'] +
# 	617*x['Chesterfield_County','Staunton'] +
# 	68.72*x['City_of_Fredericksburg','Staunton'] +
# 	224.48*x['Culpeper_County','Staunton'] +
# 	65.36*x['Cumberland_County','Staunton'] +
# 	5280*x['Dinwiddie_County','Staunton'] +
# 	5480*x['Essex_County','Staunton'] +
# 	438.4*x['Fauquier_County','Staunton'] +
# 	164.04*x['Greene_County','Staunton'] +
# 	172.44*x['Hanover_County','Staunton'] +
# 	460*x['James_City_County','Staunton'] +
# 	2740*x['King_and_Queen_County','Staunton'] +
# 	1350*x['King_George_County','Staunton'] +
# 	460*x['King_William_County','Staunton'] +
# 	163.92*x['Madison_County','Staunton'] +
# 	460*x['New_Kent_County','Staunton'] +
# 	165.12*x['Orange_County','Staunton'] +
# 	203.56*x['Page_County','Staunton'] +
# 	73.28*x['Powhatan_County','Staunton'] +
# 	860*x['Prince_George_County','Staunton'] +
# 	9315*x['Prince_William_County','Staunton'] +
# 	168.72*x['Rappahannock_County','Staunton'] +
# 	480.16*x['Rockbridge_County','Staunton'] +
# 	3513*x['Rockingham_County','Staunton'] +
# 	136*x['Shenandoah_County','Staunton'] +
# 	174.6*x['Spotsylvania_County','Staunton'] +
# 	900*x['Stafford_County','Staunton'] +
# 	920*x['Westmoreland_County','Staunton'] <= 9100;
#
# subject to HoursConstraint['Staunton','Marketing']:
# 	121.08*x['Albemarle_County','Staunton'] +
# 	10.16*x['Amherst_County','Staunton'] +
# 	260*x['Augusta_County','Staunton'] +
# 	123*x['Buckingham_County','Staunton'] +
# 	1010*x['Caroline_County','Staunton'] +
# 	2040*x['Charles_City_County','Staunton'] +
# 	2544*x['Chesterfield_County','Staunton'] +
# 	20.88*x['Cumberland_County','Staunton'] +
# 	2960*x['Dinwiddie_County','Staunton'] +
# 	5200*x['Essex_County','Staunton'] +
# 	395.24*x['Fauquier_County','Staunton'] +
# 	10*x['Fluvanna_County','Staunton'] +
# 	105.62*x['Goochland_County','Staunton'] +
# 	274.8*x['Hanover_County','Staunton'] +
# 	3284*x['Henrico_County','Staunton'] +
# 	2040*x['King_and_Queen_County','Staunton'] +
# 	2040*x['King_William_County','Staunton'] +
# 	208*x['Louisa_County','Staunton'] + 1010*x['Mathews_County','Staunton']
# 	 + 9.46*x['Nelson_County','Staunton'] +
# 	5200*x['New_Kent_County','Staunton'] +
# 	16.48*x['Page_County','Staunton'] +
# 	28.64*x['Powhatan_County','Staunton'] +
# 	1652*x['Prince_George_County','Staunton'] +
# 	3856*x['Prince_William_County','Staunton'] +
# 	246.88*x['Rockbridge_County','Staunton'] +
# 	304.64*x['Rockingham_County','Staunton'] +
# 	8*x['Shenandoah_County','Staunton'] + 5*x['Warren_County','Staunton']
# 	 + 1010*x['Westmoreland_County','Staunton'] +
# 	1010*x['York_County','Staunton'] <= 1700;
#
# subject to HoursConstraint['Staunton','Merchandising']:
# 	96.6*x['Albemarle_County','Staunton'] +
# 	65*x['Augusta_County','Staunton'] +
# 	69.4*x['Buckingham_County','Staunton'] +
# 	855*x['Caroline_County','Staunton'] +
# 	215*x['Charles_City_County','Staunton'] +
# 	608*x['Chesterfield_County','Staunton'] +
# 	96.16*x['City_of_Fredericksburg','Staunton'] +
# 	202*x['City_of_Richmond','Staunton'] +
# 	135.3*x['Culpeper_County','Staunton'] +
# 	1050*x['Dinwiddie_County','Staunton'] +
# 	280*x['Essex_County','Staunton'] +
# 	214.24*x['Fauquier_County','Staunton'] +
# 	10.48*x['Goochland_County','Staunton'] +
# 	44.68*x['Greene_County','Staunton'] +
# 	142.44*x['Hanover_County','Staunton'] +
# 	878*x['Henrico_County','Staunton'] +
# 	404*x['Hopewell_County','Staunton'] +
# 	1940*x['James_City_County','Staunton'] +
# 	460*x['King_and_Queen_County','Staunton'] +
# 	870*x['King_George_County','Staunton'] +
# 	460*x['King_William_County','Staunton'] +
# 	225*x['Louisa_County','Staunton'] +
# 	49.28*x['Madison_County','Staunton'] +
# 	1260*x['Mathews_County','Staunton'] +
# 	860*x['New_Kent_County','Staunton'] +
# 	30.04*x['Orange_County','Staunton'] + 71.8*x['Page_County','Staunton']
# 	 + 14888*x['Prince_William_County','Staunton'] +
# 	148.72*x['Rappahannock_County','Staunton'] +
# 	41.92*x['Rockbridge_County','Staunton'] +
# 	91*x['Rockingham_County','Staunton'] +
# 	45*x['Shenandoah_County','Staunton'] +
# 	114.6*x['Spotsylvania_County','Staunton'] +
# 	1110*x['Stafford_County','Staunton'] + 11*x['Warren_County','Staunton']
# 	 + 640*x['Westmoreland_County','Staunton'] +
# 	1250*x['York_County','Staunton'] <= 1850;

# %%
ampl.setOption('solver', 'cplex')
ampl.solve()
# Out:
# CPLEX 22.1.1: optimal solution; objective 195479.31
# 17 simplex iterations
# absmipgap=2.91038e-11, relmipgap=0

# %%
# Print the objective function value (Total Cost)
obj = ampl.getObjective('TotalCost')
print("\n===== Optimization Results =====\n")
print(f"Total Cost is: {obj.get().value():.2f}\n")  # Format to 2 decimal places

# Display the values of decision variables (store-to-region assignments)
print("Store-to-Region Assignments (Decision Variables):")
ampl.display('x')

# Display base hours required for each store and area
print("\nBase Hours Required by Stores and Areas:")
ampl.display('base_hours_required')

# Display available hours for each region and area
print("\nHours Available for Regions and Areas:")
ampl.display('hours_available')

# Display travel time parameter
print("\nTravel Time Parameter:")
ampl.display('travel_time')

# Display round trips parameter
print("\nRound Trips Parameter:")
ampl.display('round_trips')

# Display mileage parameter
print("\nMileage Parameter:")
ampl.display('mileage')
# Out:
# ===== Optimization Results =====
#
# Total Cost is: 195479.31
#
# Store-to-Region Assignments (Decision Variables):
# x [*,*]
# :                      Richmond Staunton Tappahannock Warrenton    :=
# Albemarle_County           0        1          0           0
# Amherst_County             0        1          0           0
# Augusta_County             0        1          0           0
# Buckingham_County          0        1          0           0
# Caroline_County            0        0          1           0
# Charles_City_County        1        0          0           0
# Chesterfield_County        1        0          0           0
# City_of_Fredericksburg     0        0          1           0
# City_of_Richmond           1        0          0           0
# Culpeper_County            0        0          0           1
# Cumberland_County          1        0          0           0
# Dinwiddie_County           1        0          0           0
# Essex_County               0        0          1           0
# Fauquier_County            0        0          0           1
# Fluvanna_County            1        0          0           0
# Goochland_County           1        0          0           0
# Greene_County              0        1          0           0
# Hanover_County             1        0          0           0
# Henrico_County             1        0          0           0
# Hopewell_County            1        0          0           0
# James_City_County          1        0          0           0
# King_George_County         0        0          1           0
# King_William_County        0        0          1           0
# King_and_Queen_County      0        0          1           0
# Louisa_County              1        0          0           0
# Madison_County             0        1          0           0
# Mathews_County             0        0          1           0
# Nelson_County              0        1          0           0
# New_Kent_County            1        0          0           0
# Orange_County              0        0          0           1
# Page_County                0        0          0           1
# Powhatan_County            1        0          0           0
# Prince_George_County       1        0          0           0
# Prince_William_County      0        0          0           1
# Rappahannock_County        0        0          0           1
# Rockbridge_County          0        1          0           0
# Rockingham_County          0        1          0           0
# Shenandoah_County          0        0          0           1
# Spotsylvania_County        0        0          1           0
# Stafford_County            1        0          0           0
# Warren_County              0        0          0           1
# Westmoreland_County        0        0          1           0
# York_County                0        0          1           0
# ;
#
#
# Base Hours Required by Stores and Areas:
# base_hours_required [*,*]
# :                      Hiring Inventory Marketing Merchandising Payroll    :=
# Albemarle_County            0     460        96          90        771
# Amherst_County              0       2         8           0         28
# Augusta_County           2806     341       260          65        737
# Buckingham_County         408      46        84          59         40
# Caroline_County           170      13        10          55        136
# Charles_City_County         0      90        40          15         26
# Chesterfield_County        17     655       144           8        343
# City_of_Fredericksburg     60     123         0          70         64
# City_of_Richmond            0     468         0           2        264
# Culpeper_County           200      12         0         120         96
# Cumberland_County           0      21        14           0         33
# Dinwiddie_County          480     300       160          50        188
# Essex_County              680      63       200          80         30
# Fauquier_County           280      55       320          40        228
# Fluvanna_County             0       4         8           0         96
# Goochland_County            0      12        70           5         97
# Greene_County             150      36         0          40         88
# Hanover_County            150       0       200         120        184
# Henrico_County              0      96        84          78        227
# Hopewell_County             0       7         0           4         36
# James_City_County          60     350         0         140        127
# King_George_County        150      16         0          70         56
# King_William_County        60      30        40          60         70
# King_and_Queen_County     340      25        40          60         14
# Louisa_County               0     270         8          25        114
# Madison_County            150      21         0          40         32
# Mathews_County              0     220        10          60         21
# Nelson_County               0      14         8           0         71
# New_Kent_County            60      15       200          60         52
# Orange_County             150      27         0          25        136
# Page_County               176     100         8          40        170
# Powhatan_County            60      16        22           0        148
# Prince_George_County       60       8        52           0         24
# Prince_William_County     315     332       256         288        385
# Rappahannock_County       150       0         0         130          8
# Rockbridge_County         450     101       226          28        470
# Rockingham_County        3175     600       288          65        761
# Shenandoah_County         120     100         4          25         97
# Spotsylvania_County       150       8         0          90        192
# Stafford_County           100      16         0         110        200
# Warren_County               0       2         2           5        121
# Westmoreland_County       120     105        10          40         17
# York_County                 0      30        10          50         91
# ;
#
#
# Hours Available for Regions and Areas:
# hours_available :=
# Richmond     Hiring          1225
# Richmond     Inventory       5000
# Richmond     Marketing       1750
# Richmond     Merchandising   3675
# Richmond     Payroll         3025
# Staunton     Hiring          9100
# Staunton     Inventory       3550
# Staunton     Marketing       1700
# Staunton     Merchandising   1850
# Staunton     Payroll         3450
# Tappahannock Hiring          3250
# Tappahannock Inventory       3400
# Tappahannock Marketing       1200
# Tappahannock Merchandising   1600
# Tappahannock Payroll         5550
# Warrenton    Hiring          3375
# Warrenton    Inventory        825
# Warrenton    Marketing       1325
# Warrenton    Merchandising    850
# Warrenton    Payroll         2500
# ;
#
#
# Travel Time Parameter:
# travel_time [*,*]
# :                      Richmond Staunton Tappahannock Warrenton    :=
# Albemarle_County           1.22     0.66       2          1.56
# Amherst_County             2.1      1.08     100        100
# Augusta_County           100        0        100          2.06
# Buckingham_County          1.55     1.3      100          2.43
# Caroline_County            0.78   100          0.82       1.45
# Charles_City_County        0.78   100          1.52     100
# Chesterfield_County        0.38   100          1.32       2.08
# City_of_Fredericksburg     1.03     2.18       1.08       0.96
# City_of_Richmond           0      100          0.98       1.85
# Culpeper_County            1.75     1.53       1.93       0.6
# Cumberland_County          1.13     1.72       2.03       2.43
# Dinwiddie_County           0.75   100          1.68     100
# Essex_County               1      100          0          1.95
# Fauquier_County          100        1.98       1.96       0
# Fluvanna_County            1.1      1          1.88       1.65
# Goochland_County           0.63     1.37       1.42       1.93
# Greene_County              1.57     1.17       2.38       1.21
# Hanover_County             0.45     1.87       0.87       1.58
# Henrico_County             0      100        100          1.75
# Hopewell_County            0.5    100          1.25     100
# James_City_County          0.88   100          1.42     100
# King_George_County         1.22   100          0.73       1.33
# King_William_County        0.75   100          0.55       2.01
# King_and_Queen_County      0.97   100          0.42       2.25
# Louisa_County              1.05   100          1.85       1.32
# Madison_County             1.61     1.16       2.18       0.92
# Mathews_County             1.5    100          1.13     100
# Nelson_County              2.1      0.73     100          2.11
# New_Kent_County            0.55   100          1.13     100
# Orange_County              1.35     1.26       1.83       1
# Page_County              100        1.06     100          1.05
# Powhatan_County            0.75     1.66       1.7        2.25
# Prince_George_County       0.45   100          1.38     100
# Prince_William_County      1.75   100          1.95       0.58
# Rappahannock_County        2.2      1.56       2.48       0.5
# Rockbridge_County        100        0.58     100        100
# Rockingham_County        100        0.52     100          1.65
# Shenandoah_County        100        1        100          1.03
# Spotsylvania_County        1.03     2.05       1.22       1.13
# Stafford_County            1.08   100          1.28       0.96
# Warren_County            100        1.5      100          0.75
# Westmoreland_County        1.42   100          0.4        1.87
# York_County                1.12   100          1.12     100
# ;
#
#
# Round Trips Parameter:
# round_trips [*,*]
# :                      Hiring Inventory Marketing Merchandising Payroll    :=
# Albemarle_County           0       78       38           10        266
# Amherst_County             0        0        2            0         22
# Augusta_County           372      184       60           60        182
# Buckingham_County         46        4       30            8          4
# Caroline_County           12        8       10            8         34
# Charles_City_County        0       56       20            2         12
# Chesterfield_County        6      110       24            6        160
# City_of_Fredericksburg     4       38        0           12         16
# City_of_Richmond           0       82        0            2        140
# Culpeper_County           16        8        0           10         24
# Cumberland_County         38       14        4            0         16
# Dinwiddie_County          48       70       28           10         92
# Essex_County              48       22       50            2         36
# Fauquier_County           80       44       38           88         72
# Fluvanna_County            0        0        2            0         48
# Goochland_County           0        2       26            4         68
# Greene_County             12       10        0            4         22
# Hanover_County            12        0       40           12         46
# Henrico_County             0       26       32            8        142
# Hopewell_County            0        2        0            4         12
# James_City_County          4       60        0           18         84
# King_George_County        12        6        0            8         14
# King_William_County        4       10       20            4         28
# King_and_Queen_County     24        4       20            4         12
# Louisa_County              0       32        2            2         84
# Madison_County            12       10        0            8          8
# Mathews_County             0       12       10           12         20
# Nelson_County              0        4        2            0         52
# New_Kent_County            4        6       50            8         44
# Orange_County             12       16        0            4         34
# Page_County               26       16        8           30         28
# Powhatan_County            8        2        4            0         60
# Prince_George_County       8        2       16            0         14
# Prince_William_County     90       86       36          146        120
# Rappahannock_County       12        0        0           12          2
# Rockbridge_County         52      146       36           24         92
# Rockingham_County        650       92       32           50        136
# Shenandoah_County         16       16        4           20         18
# Spotsylvania_County       12        4        0           12         48
# Stafford_County            8        8        0           10         50
# Warren_County              0       32        2            4         14
# Westmoreland_County        8       28       10            6         16
# York_County                0       12       10           12         80
# ;
#
#
# Mileage Parameter:
# mileage [*,*]
# :                      Richmond Staunton Tappahannock Warrenton    :=
# Albemarle_County            70       37        110         71
# Amherst_County             120       56       1000       1000
# Augusta_County            1000        0       1000        121
# Buckingham_County           72       66       1000        108
# Caroline_County             42     1000         38         62
# Charles_City_County         37     1000         72       1000
# Chesterfield_County         20     1000         65        112
# City_of_Fredericksburg      59      111         47         38
# City_of_Richmond             0     1000         46         84
# Culpeper_County             89       80         84         25
# Cumberland_County           53       88        101        108
# Dinwiddie_County            40     1000         85       1000
# Essex_County                46     1000          0         89
# Fauquier_County           1000      118         89          0
# Fluvanna_County             64       59        104         73
# Goochland_County            32       81         72         86
# Greene_County               86       59        114         56
# Hanover_County              24      115         42         82
# Henrico_County               0     1000       1000         93
# Hopewell_County             22     1000         64       1000
# James_City_County           52     1000         72       1000
# King_George_County          62     1000         36         58
# King_William_County         32     1000         25         98
# King_and_Queen_County       43     1000         19        109
# Louisa_County               55     1000         95         58
# Madison_County              86       63        102         42
# Mathews_County              73     1000         53       1000
# Nelson_County              102       38       1000        100
# New_Kent_County             29     1000         54       1000
# Orange_County               76       72         87         43
# Page_County               1000       57       1000         44
# Powhatan_County             34       93         82         98
# Prince_George_County        24     1000         68       1000
# Prince_William_County       96     1000         91         22
# Rappahannock_County        119       79        111         22
# Rockbridge_County         1000       35       1000       1000
# Rockingham_County         1000       26       1000         95
# Shenandoah_County         1000       64       1000         56
# Spotsylvania_County         59      106         54         47
# Stafford_County             67     1000         62         42
# Warren_County             1000       88       1000         33
# Westmoreland_County         65     1000         19         84
# York_County                 64     1000         59       1000
# ;

# %%
# Calculate and print hours assigned to each region across individual areas
print("\n===== Assigned Hours to Each Region Across Individual Areas =====\n")

# Initialize a dictionary to store the assigned hours for each region and area
assigned_hours_by_area = {region: {area: 0 for area in A} for region in R}

# Iterate over regions, areas, and stores to compute assigned hours
for region in R:
    for area in A:
        for store in S:
            # Combine base hours and travel hours based on assignment
            assigned_hours_by_area[region][area] += (
                ampl.getVariable('x').get(store, region).value() *  # Decision variable
                (
                    ampl.param['base_hours_required'][(store, area)]  # Base hours
                    + ampl.param['round_trips'][(store, area)] * ampl.param['travel_time'][(store, region)]  # Travel hours
                )
            )

# Print the results
for region, areas in assigned_hours_by_area.items():
    print(f"Region: {region}")
    for area, hours in areas.items():
        print(f"  Area: {area}, Assigned Hours: {hours:.2f}")
    print()  # Add a blank line after each region
# Out:
# ===== Assigned Hours to Each Region Across Individual Areas =====
#
# Region: Richmond
#   Area: Inventory, Assigned Hours: 2584.80
#   Area: Payroll, Assigned Hours: 2730.20
#   Area: Hiring, Assigned Hours: 1097.58
#   Area: Marketing, Assigned Hours: 1128.62
#   Area: Merchandising, Assigned Hours: 671.40
#
# Region: Tappahannock
#   Area: Inventory, Assigned Hours: 735.24
#   Area: Payroll, Assigned Hours: 943.98
#   Area: Hiring, Assigned Hours: 1783.04
#   Area: Marketing, Assigned Hours: 374.10
#   Area: Merchandising, Assigned Hours: 708.28
#
# Region: Warrenton
#   Area: Inventory, Assigned Hours: 755.96
#   Area: Payroll, Assigned Hours: 1418.44
#   Area: Hiring, Assigned Hours: 1514.58
#   Area: Marketing, Assigned Hours: 624.90
#   Area: Merchandising, Assigned Hours: 828.78
#
# Region: Staunton
#   Area: Inventory, Assigned Hours: 1836.42
#   Area: Payroll, Assigned Hours: 3399.58
#   Area: Hiring, Assigned Hours: 7594.92
#   Area: Marketing, Assigned Hours: 1075.22
#   Area: Merchandising, Assigned Hours: 457.88
